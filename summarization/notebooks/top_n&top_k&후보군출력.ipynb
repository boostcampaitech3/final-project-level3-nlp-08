# %%
import logging
import os
import datasets.arrow_dataset as da

from transformers import BartForConditionalGeneration, AutoConfig
from transformers.trainer_utils import get_last_checkpoint

import torch

# %%
from transformers import AutoConfig
config = AutoConfig.from_pretrained('gogamza/kobart-base-v2')
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
model = BartForConditionalGeneration(config)

# %%
model.load_state_dict(torch.load('./tmp/cache_data/model.pt'))
# Out:
# <All keys matched successfully>

# %%
import os
import json
import pandas as pd
from pandas import json_normalize

json_data = []

for filename in os.listdir("tmp/data/Validation"):
   with open(os.path.join("tmp/data/Validation", filename), 'r') as f:
        json_data.append(json.load(f))

# %%
from tqdm import tqdm

# %%
df = pd.concat([json_normalize(json_data[i]['data']) for i in tqdm(range(len(json_data)))])
# Out:
# 100%|██████████| 9/9 [00:08<00:00,  1.03it/s]

# %%
dict_data = {'dialogue':df['body.dialogue'], 'summary':df['body.summary'], 'id':df['header.dialogueInfo.dialogueID']}

# %%
return_df = pd.DataFrame(data=dict_data)

# %%
def generate_summary(test_samples, model, tokenizer, encoder_max_length):
    inputs = tokenizer(
        test_samples["dialogue"],
        padding="max_length",
        truncation=True,
        max_length=encoder_max_length,
        return_tensors="pt",
    )

    input_ids = inputs.input_ids.to(model.device)
    attention_mask = inputs.attention_mask.to(model.device)
    outputs = model.generate(input_ids, attention_mask=attention_mask)
    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return outputs, output_str

# %%
def flatten(example):
    dialogue_list = []

    for dict_data in example['dialogue']:
        return_string = ""
        for string in dict_data:
            return_string += string['participantID'] + ": " + string['utterance'] + "\r\n"

        dialogue_list.append(return_string[:-2])

    return {
        "dialogue": dialogue_list,
        "summary": example['summary']
    }

# %%
import datasets.arrow_dataset as da

# %%
sample_dataset = da.Dataset.from_pandas(return_df)

# %%
from transformers import PreTrainedTokenizerFast

# %%
from typing import Optional

# %%
class MyTokenizer(PreTrainedTokenizerFast):
    def __init__(self,*args, **kwargs):
        super().__init__(*args, **kwargs)
    
    def save_vocabulary(self, save_directory: str, filename_prefix: Optional[str] = None):
        return (1,)

# %%
sample_dataset = sample_dataset.map(flatten, remove_columns=['id'], batched=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=36.0), HTML(value='')))

# %%
tokenizer = MyTokenizer.from_pretrained('gogamza/kobart-base-v2')
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'PreTrainedTokenizerFast'.
# The class this function is called from is 'MyTokenizer'.

# %%
encoder_max_length = 1024
decoder_max_length = 128

# %%
def generate_summary(test_samples, model):
    inputs = tokenizer(
        test_samples["dialogue"],
        padding="max_length",
        truncation=True,
        max_length=encoder_max_length,
        return_tensors="pt",
    )
    
    input_ids = inputs.input_ids.to(model.device)
    attention_mask = inputs.attention_mask.to(model.device)
    outputs = model.generate(input_ids, 
                             num_beams=5,
                             max_length=64,
                             num_return_sequences=3, #3개의 결과를 디코딩해낸다
                             attention_mask=attention_mask,    
                             top_k=50, # 확률 순위가 50위 밖인 토큰은 샘플링에서 제외
                            top_p=0.95, # 누적 확률이 95%인 후보집합에서만 생성
                            )

    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    return outputs, output_str

# %%
pred_list = []
golden_list = []

for i in tqdm(range(50)):
    pred_list.append(generate_summary(sample_dataset[10*i:10*(i+1)],model)[1])
    golden_list.append(sample_dataset[10*i:10*(i+1)]['summary'])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
#   2%|▏         | 1/50 [00:25<20:47, 25.45s/it]
#
#
#
#
#
#   4%|▍         | 2/50 [00:52<20:49, 26.03s/it]
#
#
#
#
#
#   6%|▌         | 3/50 [01:23<21:29, 27.44s/it]
#
#
#
#
#
#   8%|▊         | 4/50 [01:47<20:19, 26.50s/it]
#
#
#
#
#
#  10%|█         | 5/50 [02:13<19:34, 26.11s/it]
#
#
#
#
#
#  12%|█▏        | 6/50 [02:39<19:13, 26.22s/it]
#
#
#
#
#
#  14%|█▍        | 7/50 [03:07<19:03, 26.59s/it]
#
#
#
#
#
#  16%|█▌        | 8/50 [03:39<19:45, 28.22s/it]
#
#
#
#
#
#  18%|█▊        | 9/50 [04:12<20:20, 29.77s/it]
#
#
#
#
#
#  20%|██        | 10/50 [04:42<19:50, 29.77s/it]
#
#
#
#
#
#  22%|██▏       | 11/50 [05:12<19:25, 29.89s/it]
#
#
#
#
#
#  24%|██▍       | 12/50 [05:40<18:41, 29.52s/it]
#
#
#
#
#
#  26%|██▌       | 13/50 [06:06<17:23, 28.19s/it]
#
#
#
#
#
#  28%|██▊       | 14/50 [06:33<16:51, 28.10s/it]
#
#
#
#
#
#  30%|███       | 15/50 [06:59<15:54, 27.27s/it]
#
#
#
#
#
#  32%|███▏      | 16/50 [07:26<15:22, 27.12s/it]
#
#
#
#
#
#  34%|███▍      | 17/50 [07:57<15:39, 28.46s/it]
#
#
#
#
#
#  36%|███▌      | 18/50 [08:25<15:00, 28.14s/it]
#
#
#
#
#
#  38%|███▊      | 19/50 [08:53<14:31, 28.11s/it]
#
#
#
#
#
#  40%|████      | 20/50 [09:16<13:22, 26.76s/it]
#
#
#
#
#
#  42%|████▏     | 21/50 [09:45<13:13, 27.35s/it]
#
#
#
#
#
#  44%|████▍     | 22/50 [10:08<12:09, 26.06s/it]
#
#
#
#
#
#  46%|████▌     | 23/50 [10:32<11:23, 25.32s/it]
#
#
#
#
#
#  48%|████▊     | 24/50 [10:54<10:33, 24.36s/it]
#
#
#
#
#
#  50%|█████     | 25/50 [11:17<09:57, 23.90s/it]
#
#
#
#
#
#  52%|█████▏    | 26/50 [11:39<09:22, 23.44s/it]
#
#
#
#
#
#  54%|█████▍    | 27/50 [12:02<08:53, 23.20s/it]
#
#
#
#
#
#  56%|█████▌    | 28/50 [12:24<08:23, 22.88s/it]
#
#
#
#
#
#  58%|█████▊    | 29/50 [12:46<07:59, 22.86s/it]
#
#
#
#
#
#  60%|██████    | 30/50 [13:09<07:35, 22.77s/it]
#
#
#
#
#
#  62%|██████▏   | 31/50 [13:32<07:15, 22.90s/it]
#
#
#
#
#
#  64%|██████▍   | 32/50 [13:55<06:51, 22.84s/it]
#
#
#
#
#
#  66%|██████▌   | 33/50 [14:18<06:27, 22.79s/it]
#
#
#
#
#
#  68%|██████▊   | 34/50 [14:40<06:04, 22.80s/it]
#
#
#
#
#
#  70%|███████   | 35/50 [15:04<05:44, 22.98s/it]
#
#
#
#
#
#  72%|███████▏  | 36/50 [15:26<05:20, 22.86s/it]
#
#
#
#
#
#  74%|███████▍  | 37/50 [15:49<04:55, 22.76s/it]
#
#
#
#
#
#  76%|███████▌  | 38/50 [16:12<04:35, 22.97s/it]
#
#
#
#
#
#  78%|███████▊  | 39/50 [16:35<04:11, 22.85s/it]
#
#
#
#
#
#  80%|████████  | 40/50 [16:58<03:48, 22.81s/it]
#
#
#
#
#
#  82%|████████▏ | 41/50 [17:21<03:26, 22.99s/it]
#
#
#
#
#
#  84%|████████▍ | 42/50 [17:44<03:03, 22.91s/it]
#
#
#
#
#
#  86%|████████▌ | 43/50 [18:07<02:41, 23.07s/it]
#
#
#
#
#
#  88%|████████▊ | 44/50 [18:30<02:17, 22.98s/it]
#
#
#
#
#
#  90%|█████████ | 45/50 [18:53<01:55, 23.02s/it]
#
#
#
#
#
#  92%|█████████▏| 46/50 [19:16<01:31, 22.90s/it]
#
#
#
#
#
#  94%|█████████▍| 47/50 [19:39<01:08, 22.96s/it]
#
#
#
#
#
#  96%|█████████▌| 48/50 [20:02<00:45, 22.92s/it]
#
#
#
#
#
#  98%|█████████▊| 49/50 [20:25<00:23, 23.01s/it]

# %%
import nltk

# %%
def postprocess_text_first_sent(preds):
    preds = [pred.strip() for pred in preds]
    preds = [pred[:pred.index(".")+1] if "." in pred else pred for pred in preds]
    
    # preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]

    return preds

# %%
print(pred_list[0][3])
# Out:
# 수유로에서 집 데려다주려고 하는데 집에 데려다주지 않는다.

# %%
for i in range(len(pred_list)):
    pred_list[i] = postprocess_text_first_sent(pred_list[i])
    for j in range(len(golden_list[i])):
        print(pred_list[i][j*3:(j+1)*3])
        print(golden_list[i][j])
        print()
# Out:
# ['수유로 오라고 해서 지금 가도 되냐고 물으니 집에 데려다주냐고 한다.', '수유로 오라고 해서 지금 가도 되냐고 물으니 안된다고 한다.', '수유로 오라고 해서 지금 가도 되냐고 물으니 집에 데려다주냐고 해서']
# 지금 수유에 갈 테니 집에 데려다 달라고 한다.
#
# ['제주도가 가고 싶어서 2박 3일 동안 갔다 올 수 있을 것 같다고 한다.', '제주도를 가고 싶은데 쉬는 날 몰라서 못 갈 것 같다.', '제주도가 가고 싶어서 2박 3일 동안 갔다 올 수 있을 것 같다고 하자']
# 2박 3일 정도 쉬는 날을 몰아서 제주도에 갔다 오기로 했다.
#
# ['메가박스 2시 45분 매표소나 역출구보다 역출구 매표', '메가박스 2시 45분 매표소나 역출구보다 매표소가 낫지', '메가박스 2시 45분 매표소나 역출구가 나을 것 같다고 하자']
# 메가박스 매표소에서 2시 45분에 만나기로 약속했다.
#
# ['내일 상황을 봐서 밥을 정하고 간지 카페에 가기로 한다.', '내일 상황을 봐서 밥을 정하고 간지 카페에 가자고 한다.', '내일 상황을 봐서 밥을 정하고 간지 카페에 가자고 한다.']
# 내일 상황을 봐서 정하자고 카페를 가서 힐링해야 한다고 한다.
#
# ['내일 모레 김장김치와 수육을 먹으러 가기로 했다.', '내일 모레 김장김치와 수육을 먹으러 가기로 했다.', '내일 모레 김장김치랑 수육을 먹으러 가기로 했다.']
# 모레 김장 김치와 수육을 먹을 테니 집으로 오라고 한다.
#
# ['제주도에서 숙소를 예약하고 있는데 전날까지 고통받는다.', '제주도에서 숙소를 예약하고 있는데 전날까지 고통받는다.', '제주도에서 숙소를 예약하고 있는데 전날까지 고통받는다고 한다.']
# 동생이 언니에게 자냐며 잘 다녀오라고 하자 언니는 제주도 숙소를 예약하고 있다며 빨리하고 자야겠다고 한다.
#
# ['40분쯤에 도착할 것 같으니 시간을 봐서 카페에 가려고 한다.', '40분쯤에 도착할 것 같으니 시간을 봐서 카페에 가려고 한다.', '40분쯤에 도착할 것 같으니 시간을 봐서 모닝커피를 마시라고 한다.']
# 40분쯤 도착할 것 같으니 먼저 카페에 가서 커피를 마시고 있으면 그쪽으로 가겠다고 한다.
#
# ['내일은 형부 전시에 갈 곳이 많아서 닭발을 먹자고 한다.', '내일은 형부 전시에 갈 곳이 많아서 닭발을 먹자고 한다.', '내일은 형부 전시에 갈 곳이 많아서 닭발을 먹기로 한다.']
# 내일 형부의 전시를 보러 가던지 닭발을 먹으러 가기로 한다.
#
# ['오늘 피부과에 가느라 늦게 잘 것 같아서 본가에 가서 자고 내일 드레스 투어', '오늘 피부과에 가느라 늦게 잘 것 같아서 본가에 가서 자고 내일 드레스 투', '오늘 피부과에 가느라 늦게 자서 오늘 만나기가 힘들 것 같다고 이야기한다.']
# 피부과 때문에 늦게 잘 것 같아서 오늘 만나기 힘들 것 같다는 이야기를 하고 있다.
#
# ['지금 상태로는 7시에 갈 것 같으니 좀 늦게 먹자고 한다.', '지금 상태로는 7시까지 갈 수 있을 것 같다고 하자 배가 안 고플 것 같', '지금 상태로는 7시까지 갈 수 있을 것 같으니 좀 늦게 먹자고 한다.']
# 배가 안 고플 것 같아서 조금 늦게 밥을 먹기 위해 7시쯤에 보기로 했다.
#
# ['2시간 전에 출발해야 하는데 시간을 착각해서 3시에 출발한 것 같다.', '2시간 전에 출발해야 하는데 3시에 출발한 것 같다고 하자 수고했다고 한다.', '2시간 전에 출발해야 하는데 시간을 착각해서 3시에 출발한 것 같다고 한다.']
# 시간을 착각해서 3시에 출발해서 지금(짐) 가는 중이다.
#
# ['오후 비행기(뱅기)가 싸서 4시 비행기(뱅기)가 경쟁률도 낮', '오후 비행기(뱅기)가 싸서 4시 비행기(뱅기)가 싸서 4시 비행', '오후 비행기(뱅기)가 싸서 4시 비행기(뱅기)가 경쟁률이 낮을']
# 비행기 시간은 오후면 좋겠다고 하자 4시 비행기가 경쟁률이 낮지 않을까 예상한다고 해서 그랬으면 좋겠다고 한다.
#
# ['토요일에 영화를 보고 야행을 가려고 한다.', '토요일에 영화를 보고 야행을 갈지 고민하고 있다.', '토요일에 영화를 보고 야행을 가려고 한다.']
# 토요일 영화 시간표는 수요일에 나오니 시간을 보고 영화를 볼 것인지 정하자고 한다.
#
# ['다음 주 월요일에 전화 사주 예약을 했는데 잘 맞을지 기대된다.', '다음 주 월요일에 전화 사주를 예약해뒀는데 잘 맞을지 기대된', '다음 주 월요일에 전화 사주를 예약해 놨는데 잘 맞으면 보려']
# 유명한 곳에 전화 사주 예약을 해놓고 기대하고 있다.
#
# ['8시에 끝나서 같이 밥을 먹을까 고민했는데 너무 배고파서 지하철 타고 수', '8시에 끝나서 같이 밥을 먹을까 고민했는데 너무 배고파서 지하철을 타고', '8시에 끝나서 같이 밥을 먹을까 고민했는데 너무 배가 고파서 지하철을 타고']
# 같이 밥을 먹자 하려 했다고 하며 지하철을 타고 수유로 빨리 오라고 하고 있다.
#
# ['6시에 만나서 막창을 먹으려고 한다.', '6시 반에 만나서 막창을 먹기로 했다.', '6시 반에 만나서 막창을 먹기로 했다.']
# 6시에 막창을 먹는다고 하자 자신도 6시 30분 정도에는 갈 수 있다고 간다고 한다.
#
# ['가게 되면 해외여행으로 괌에 가고 싶고 미국 브랜드 아웃렛에서도 싸고', '가게 되면 해외여행으로 괌에 가고 싶고 미국 브랜드 아웃렛에서 엄청 싸', '가게 되면 해외여행으로 괌에 가고 싶고 미국 브랜드 아웃렛에 가서 쇼핑']
# 해외로 여행을 괌으로 가고 싶은데 미국 브랜드 아웃렛도 매우 저렴하다고 하니 가서 쇼핑도 하고 싶다.
#
# ['병원에 한시 반에 도착하는 것으로 하자고 해서 같이 나가야겠다고 한다.', '병원에 한시 반에 도착하는 걸로 하자고 한다.', '병원에 한시 반에 도착하는 것으로 하자고 해서 같이 나가야겠다고 이야기한다.']
# 병원에 한시 반에 도착하는 걸로 하고 같이 나가자고 한다.
#
# ['수요일에 언니네 집에 갈지 안 갈지에 대해 이야기한다.', '수요일에 언니네 집에 갈지 안 갈지 이야기하고 있다.', '수요일에 언니네 집에 갈지 안 갈지에 대해 이야기하고 있다.']
# 수요일에 술 약속 있다고 말하니까, 아직 언니네 집에 갈지 안 갈지 모른다고 한다.
#
# ['독립기념관도 출근해서 회의하고 있을 것 같고 마스크, 손 소독', '독립기념관도 출근해서 회의하고 있을 것 같고 2박 3일 동안 숙박하면', '독립기념관도 출근해서 회의하고 있을 것 같고 2박 3일 동안 숙박을']
# 코로나를 방지하기 위해 마스크 비싼 거 사서 가고 손소독제도 들고 가고 손도 잘 씻어야 하는 것에 대해 이야기하고 있다.
#
# ['5월 5일에 만나서 쌍리단길에 파스타와 우육면을 먹고 산책하다가', '5월 5일에 만나서 쌍리단길에 파스타와 우육면을 먹고, 산책', '5월 5일에 만나서 쌍리단길에 파스타랑 우육면을 먹고 산책하다가']
# 5/5에 만나서 쌍리단길에서 돌아다니다가 먹고 싶은걸 먹고, 산책 후 디저트도 먹기로 하였다.
#
# ['오는 길에 탄산 아무거나 사다 달라고 했다.', '오는 길에 탄산 아무거나 사다 달라고 부탁하고 있다.', '오는 길에 탄산 아무거나 사다 달라고 한다.']
# 오는 길에 탄산 아무거나 마실 거를 사다 달라고 하였다.
#
# ['녹번역을 지나서 집에서 같이 저녁을 먹기로 했다.', '녹번역을 지나서 집에서 같이 저녁을 먹기로 했다.', '녹번역을 지나서 집에서 같이 저녁을 먹으려고 한다.']
# 들어와서 집에서 같이 저녁을 먹자며 밥을 차릴 테니 내리면 톡 주라고 하고 녹번역을 지났다고 한다.
#
# ['기내식으로 피자랑 같이 오는 오븐 스파게타 같고 먹을만한 건', '기내식으로 피자랑 같이 오는 오븐 스파게티 같고 먹을만한 건', '기내식으로 피자랑 같이 오는 오븐 스파게타 같고 먹을 만한 건']
# 기내식으로 나온 스파게티를 먹었는데 아무 맛도 없다.
#
# ['착한 낙지를 언제 한 번 가자고 한 거라 나한테 말한 거겠지라고 한다.', '착한 낙지를 언제 한 번 가자고 한 거라 나한테 말한 거겠지라고 하였', '착한 낙지를 언제 한 번 가자고 했는지 물어본다.']
# 착한 낙지 언제 한번 가자고 말한 것인데 나한테는 물어보지 않았다고 가지 않겠다고 한다.
#
# ['1박 2일로 술을 마시고 피시방에 가서 배틀그라운드(배그)를', '1박 2일로 술 마시고 피시방에 가서 배틀그라운드(배그)를', '1박 2일로 술 마시고 피시방 가서 배틀그라운드(배그)']
# 오산에서 만나 밤새도록 같이 놀자고 의지를 다지고 있다.
#
# ['온라인 미팅이 50분씩이라 너무 좋고 월요일은 두산 위브에서 오프라인', '온라인 미팅이 50분씩이라서 좋다며 월요일은 두산 위브에서', '온라인 미팅이 50분씩이라서 좋다고 하고 월요일은 두산 위브에서']
# 화요일 오전 11시와 오후 8시에 50분씩 온라인 미팅을 하는데 월요일은 두산 위브에서 오프라인 모임인지 확인한다.
#
# ['몇 시쯤 볼지 고민하다가 갤러리아에서 1시까지 보기로 한다.', '둔산에서 밥을 먹고 넘어가기로 했다.', '몇 시쯤 볼지 고민하다가 갤러리아에서 1시까지 보기로 한다.']
# 갤러리아에서 1시까지 보자고 하였다.
#
# ['매운 거 아니면 매운 거냐며 누룽지도 가져간다고 하자 사지', '매운 거 아니면 매운 거냐며 누룽지도 가져간다고 하니 사지', '매운 것을 먹지 말고 누룽지도 사지 말고 내일모레 보자고 한다.']
# 궁중 맛과 누룽지를 가져가니 사지 말라고 하며 내일모레 보자고 한다.
#
# ['오늘 수업 끝나고 집에 가서 밥을 먹기로 했다.', '오늘 수업 끝나고 집에 가서 밥을 먹기로 했다.', '오늘 수업 끝나고 집에 가서 같이 밥을 먹기로 했다.']
# 오늘은 다섯시에 수업이 끝나면 중앙 도서관(중도)에 있는 언니와 같이 집에 가서 밥을 먹기로 했다.
#
# ['일요일에 11시도 안돼서 나와야 해서 서운하다고 하자 다음 주에 가자고', '일요일에 11시도 안돼서 나와야 해서 서운하고 다른 사람들은 결혼식 끝나고 주례', '일요일에 밥만 먹고 나와야 해서 서운하다고 하자 다음 주에 가자고 한다.']
# 다음 주에 주례해 준 분께 인사를 드리러 가기로 했다.
#
# ['아껴야 돼서 휴가를 쓰려고 한다.', '아껴야 돼서 휴가를 쓰자고 한다.', '아껴야 해서 휴가를 쓰기로 했다.']
# 부산을 가기 위해 휴가를 쓰지 않고 아껴야 한다.
#
# ['내일은 공부를 해야 돼서 시내에 못 가서 북문당을 사서 자기네에', '내일은 공부를 해야 돼서 시내에 못 가서 북문당에 가서 먹기로 했다.', '내일은 공부를 해야 돼서 시내에 못 가서 북문당에 가서 먹기로 한다.']
# 다음 주 시험 보러 갈 때 상품권을 바꾸고 먹고 싶은 곳에 같이 가기로 하였다.
#
# ['이번 주에 속초가 아니라 강릉에 가는데 혼자 가면 일하다가 말고 일박', '이번 주에 속초가 아니라 강릉에 가서 시간 나면 보자고 한다.', '이번 주에 속초가 아니라 강릉에 가서 시간 나면 한번 보자고 한다.']
# 강릉에 가는데 시간이 나면 보자고 해서 만나기로 했다.
#
# ['아침 10시 버스로 예매했는데 먼저 머리 식힐 겸 혼자 돌아다니고 있을 테니', '아침 10시 버스로 예매했는데 먼저 머리 식힐 겸 혼자 돌아다니고 있을 테', '아침 10시 버스로 예매했는데 먼저 머리 식힐 겸 혼자 돌아다니고 있을 거']
# 아침 10시 버스를 예매했고 도착을 하면 한시 반 정도이고 수업을 가지 않고 만나자고 한다.
#
# ['필리피노 마켓에서 칼 들고 다니면 되니 흉기 차고 다니라고', '필리피노 마켓에서 칼 들고 다니면 덜할 것 같다.', '필리피노 마켓에서 칼 들고 다니면 되니 흉기 차고 다녀야']
# 필리피노 마켓 쪽이 베트남 저리 가라 할 정도로 캣 콜링이 심하다고 하자, 칼 들고 다니면 덜 하려나 한다.
#
# ['지금 티타임 중인데 30분까지는 갈 테니 기다리라고 한다.', '지금 티타임 중인데 혼자 가겠다고 하니 얘기가 길어져서 끊을 수 없으니', '지금 티타임 중인데 혼자 가겠다고 하니 얘기가 길어져서 끊을 수 없어 30분']
# 지금 티타임을 가지는 중인데 이야기가 길어진다며 30분까지 가겠다고 하자 그때는 데리러 가야 한다고 말한다.
#
# ['점장님 영업 회의가 잡혀서 다음 주에 강릉에 갈 수 없을 것 같', '점장님 영업 회의가 잡혀서 다다음 주에 강릉에 갈 수 있을지', '점장님 영업 회의가 잡혀서 다다음 주에 강릉에 갈 수 없다.']
# 다다음 주에 강릉을 가는 날인데 점장님 영업회의 잡혀서 뒤로 미루는 것보다는 다음 주로 당기는 게 나을 것 같다.
#
# ['집에 갈 때 스킨로션, 선크림 아무 것도 안 챙기고 가서 살고 잡', '집에 갈 때 스킨로션, 선크림 아무 것도 안 챙기고 가서 살고 싶', '집에 갈 때 스킨로션, 선크림 아무 것도 안 챙기고 가방에 담아']
# 상대방 집에 갈 때 스킨, 로션, 선크림 아무것도 가져가지 않겠다고 하자 그러라고 하고 있다.
#
# ['텐진역 지하 1층에 있는 드럭이 싸고 텐진에서 잘 필요가 없어서', '텐진역 지하 1층에 있는 드럭이 싸고 다이묘 거리 쪽에 이번에 다', '텐진역 지하 1층에 있는 드럭이 싸고 텐진에서 잘 필요가 없어']
# 숙소를 결정하기 위해 여행 계획을 확인한다.
#
# ['오늘 다 끝나서 이제 다른 곳을 돌아보지 않고 내일이나 나중에 갈 것 같다고 한다.', '오늘 다 끝나서 이제 다른 곳을 돌아보지 않고 내일이나 나중에 갈 거 같다고 한다.', '오늘 다 끝나서 이제 다른 곳을 돌아보지 않고 내일이나 나중에 갈 것 같다.']
# 아직 봐야 할 곳이 남았지만 다음에 보기로 하고 끝내려고 한다.
#
# ['12월 금요일(금방)에 만나서 연말 파티를 하기로 한다.', '12월 금요일(금방)에 만나서 연말 파티를 하기로 했다.', '12월 금요일(금방)에 만나서 연말 파티를 하자고 한다.']
# 일요일에 만나면 12월에 파티할 날짜를 정하자고 하였다.
#
# ['9월에 해수욕장이 폐장해서 가자고 했는데 일이 너무 많아서 안 간다고', '9월에 해수욕장이 폐장해서 가자고 하니 일이 너무 많아서 안 간다고', '9월에 해수욕장이 폐장해서 가자고 했는데 일이 너무 많아서 안 가겠다고']
# 9월에 해수욕장이 폐장해 가려고 하지만 일이 너무 많아서 안 간다고 이야기한다.
#
# ['이번 주 화요일 저녁에 만나서 뭘 먹을지 정하고 있다.', '이번 주 화요일 저녁에 만나서 뭘 먹을지 정하고 있다.', '이번 주 화요일 저녁에 만나서 뭘 먹을지 이야기하고 있다.']
# 이번 주 일요일은 안되니 화요일에 먹고 싶은 것을 먹자고 한다.
#
# ['결혼식이 끝나서 금정역에서 만나기로 했다.', '결혼식이 끝나서 금정역에서 만나기로 했다.', '결혼식이 끝나서 금정에서 만나기로 하고 전철을 타고 가기로 한다.']
# 신도림에서 결혼식이 끝나고 밥을 먹고 있어서 금정에서 만나서 같이 가기로 했다.
#
# ['성수기라 렌트도 어렵고 버스 타고 가도 된다.', '성수기라 렌트도 어렵고 버스 타고 가도 된다.', '성수기라 렌트도 어렵고 버스 타고 가도 되지만 렌트를 하지 말']
# 성수기라 렌트가 어려운데 버스 타고 가는 것은 불편하다.
#
# ['마카오에 도착해서 숙소에 가는 날 잠옷을 입고 잠옷을 계속 입고', '마카오에 도착해서 숙소에 가는 날 잠옷을 입고 잠옷을 입고 갈', '마카오에 도착해서 숙소에 가는 날 잠옷을 입고 잠옷을 입고 가']
# 마카오 여행을 위해 공항 갈 때 어떤 교통 편이 나을지 고민하고 있다.
#
# ['내일 오전 11시쯤 양산으로 낚시를 간다.', '내일 오전 11시쯤 양산으로 낚시를 간다.', '내일 오전 11시쯤 양산으로 낚시를 가기로 했다.']
# 내일 낚시 가는 장소와 시간을 궁금해해서 양산에 11시에 간다고 한다.
#
# ['집 앞에 있는 공주에서 수요일에 보기로 한다.', '집 앞에 있는 공주에서 수요일에 만나기로 했다.', '집 앞에 있는 공주에서 수요일에 보자고 한다.']
# 오래간만에 공주 집 앞에서 만나기로 한다.
#
# ['다음 주 화요일에 부산에 있는 야구장에 가기로 했다.', '다음 주 화요일에 부산에 있는 야구장에 가기로 했다.', '다음 주 화요일에 부산에 있는 야구장에 가기로 했다.']
# 선착순이어서 30일 화요일로 야구장 신청을 했다.
#
# ['오늘 엄마한테 놀러 간다고 말했고 내일 가서 토요일에 집에 온다니까 놀', '오늘 엄마한테 놀러 간다고 말했고 내일 가서 토요일에 집에 온다고 하니까 놀', '오늘 엄마한테 놀러 간다고 말했고 내일 가서 토요일에 집에 온다고 하니 놀']
# 오늘 엄마께 내일 놀러 가서 토요일에 놀러 가는 걸 말씀드렸다며 일정을 이야기하고 있다.
#
# ['중국어 전화가 30분 걸려서 집에 들렀다가 떡볶이를 먹자고 한다.', '중국어 전화가 30분 걸려서 집에 들렀다가 떡볶이를 먹기로 했다.', '중국어 전화가 30분 걸려서 집에 들렀다가 떡볶이를 먹자고 이야기한다.']
# 자기가 지금 너무 꼬질하니까 맘스터치(맘터)에서 떡볶이를 먹자고 한다.
#
# ['10월 중순에 만나기로 했는데 말에 뼈가 있는 것 같다고 한다.', '10월 중순에 만나기로 했는데 말에 뼈가 있는 것 같다고 하자 아니면 말라고 한다.', '10월 중순에 보기로 했는데 말에 뼈가 있는 것 같다.']
# 시험(셤)이 끝나고 10월 중순은 돼야 보겠고 말에 뼈가 있는 거 아니다.
#
# ['왜 모이라는 거냐며 이에 대해 이야기하고 있다.', '왜 모이라는 거냐며 이에 대해 이야기하고 있다.', '왜 모이라는 거냐고 하자 가면 가고 가면 안 가도 상관없지 않냐며']
# 왜 모이라고 하는지 몰라서 나가지 않기로 했다.
#
# ['단체로 움직여야 하는 분위기라 차라리 출근을 할 걸 그랬다.', '우선 친구랑 놀러 간다고 그랬으니 차라리 출근을 할 걸 그랬다.', '단체로 움직여야 하는 분위기라 차라리 출근을 할 걸 그랬다.']
# 단체로 움직여야 할 것 같아서 친구랑 놀러 간다 했다고 한다.
#
# ['곱창을 먹으러 주말에 곱창찌개를 사러 간다.', '주말에 곱창을 먹으러 간다고 한다.', '주말에 곱창을 먹으러 간다고 해서 곱창찌개를 사 오라고 한다.']
# 드디어 곱창 먹으러 간다며 이에 대해 이야기하고 있다.
#
# ['내일 바다를 보며 온천을 할 것이고 친구 속이기 딱 좋다.', '내일 바다를 보며 온천을 할 것이고 친구 속이기 딱 좋지만 다른 나라에 왔다고', '내일 바다를 보며 온천을 할 것이고 친구 속이기 딱 좋다.']
# 바다 수영과 온천을 즐길 수 있는 아주 멋진 곳에 대해 이야기한다.
#
# ['주말에 실습일지를 다 써서 다음 주에 보기로 했다.', '주말에 실습일지를 다 써서 다음 주에 보자고 한다.', '언니가 주말에 실습 일지를 다 써서 다음 주에 보기로 했다.']
# 다음 주에 보자고 하니 다 좋다며 편한 대로 하라고 한다.
#
# ['아산에 펜션 골라놓은 거 이따 보내준다고 하였다.', '펜션 골라놓은 거 이따 보내준다고 하였다.', '아산에 펜션 골라놓은 거 이따 보내준다고 했다.']
# 8월 30, 31일에 아산으로 갈 여행에 대해 이야기한다.
#
# ['순천에 가보고 싶은데 순천만을 못 봐서 큰 계획이 없어진 것 같다.', '순천에 가보고 싶은데 순천만을 못 봐서 큰 계획이 없어진 것 같다고', '순천에 가보고 싶은데 순천만 쪽을 못 가니 큰 계획이 없어진 것']
# 순천만은 못 보면 순천에 가는 의미가 없다며 큰 계획이 없어진 거 같다고 하고 있다.
#
# ['연도를 날리러 가고 싶은 곳을 고르고 있다.', '연도를 날리러 가고 싶은 곳을 고르고 있다.', '연도를 날리러 가고 싶은 곳을 고르고 있다.']
# 호우동, 스펀은 연을 날리러 가고 싶다고 해서 하루 잡아서 가자고 한다.
#
# ['갑자기 카카오톡(카톡) 하나 덕분에 비행기까지 끊었다고 하니 이래야 여행 간다고', '갑자기 카카오톡(카톡) 하나 덕분에 비행기까지 끊었다고 한다.', '갑자기 카카오톡(카톡) 하나 덕분에 비행기까지 끊었다고 하자 이래야 여행 간다고']
# 갑작스럽게 여행을 가는 것에 대해서 말한다.
#
# ['주말에 광주에 갔다가 대천에 가는데 다음 주 토요일 저녁에 시간 되면', '주말에 광주에 갔다가 대천에 가는데 다음 주 토요일 저녁에 시간이 된다고', '주말에 광주에 갔다가 대천에 가는데 다음 주 토요일 저녁에 시간이 된다.']
# 주말에 세 자매가 다 모이기는 힘들어서 시간을 맞춰보자고 했다.
#
# ['외할아버지 친할아버지가 돌아가셔서 천안에 왔는데 아빠가 너무 슬', '외할아버지와 친할아버지가 돌아가셔서 천안에 왔는데 아빠가 너무 슬', '외할아버지 친할아버지가 돌아가셔서 천안에 왔는데 슬프지만 아빠']
# 할아버지가 돌아가셔서 천안에 왔는데 아빠가 너무 슬퍼하셔서 안 울려고 한다.
#
# ['일정을 변경하고 호텔에서 쉬었다가 나오면 될 것 같다.', '일정을 변경하고 호텔에서 쉬었다가 나오면 될 것 같다.', '일정을 변경하고 호텔에서 쉬었다가 나오면 될 것 같다고 한다.']
# 여행 일정을 이야기해 주고 예약할 수 있는 것을 다 예약하려 하고 호텔에서 쉬었다가 나오면 될 것 같다.
#
# ['스콘이 이 시국에 가도 되는지 물어본다.', '스콘이 이 시국에 가도 되는지 물어본다.', '스콘이 이 시국에 가도 되는지 물어본다.']
# 스콘을 파는 가게가 열긴 하는데 이 시국에 가도 되는지 고민한다.
#
# ['언제 나갈 거냐고 물으니 이제 준비할 것 같다고 해서 나갈 때쯤 말해준', '언제 나갈 건지 확실해지면 문자로 말해도 전화할 거라고 한다.', '언제 나갈 거냐고 물으니 이제 준비할 것 같다고 해서 나갈 때쯤 말해주']
# 언제 나갈 거냐고 하자 이제 준비할 듯한데 나갈 때쯤 말해주겠다고 한다.
#
# ['여름에 정동진 해수욕장에 가자고 한다.', '여름에 정동진 해수욕장에 가자고 한다.', '여름에 정동진 해수욕장에 가서 바다만 봐도 행복할 것 같으니 꼭 가']
# 언젠가 여름에 정동진 해수욕장에 가자고 하여 바다는 언제나 좋다고 하였다.
#
# ['화요일 네시 반 영화로 예매했다.', '화요일 네시 반 영화로 예매했다고 하니 너무 고맙다고 한다.', '화요일 네시 반 영화로 예매했다고 하자 너무 고맙다고 한다.']
# 화요일(화욜) 네시 반 영화로 예매하느라 공부를 못 해서 이제부터 할 것이다.
#
# ['회사 동생이 이태리에 가고 싶다고 해서 다녀오기로 했다.', '회사 동생이 이태리에 가고 싶다고 해서 이태리에 다녀오기로 했다.', '회사 동생이 이태리에 가고 싶다고 해서 다녀오기로 했다.']
# 회사 동생이랑 이태리에 가기로 한 사람에게 서운하긴 하지만 잘 다녀오라고 말하고 있다.
#
# ['조리원 동생이 이사를 가는데 화요일과 수요일 중에 일찍 올 수 있는', '조리원 동생이 이사를 가는데 화요일과 수요일에 일찍 올 수 있는 날이', '조리원 동생이 이사를 가는데 저녁에 한 번 봐서 다음 주 월요일']
# 아내가 남편에게 월요일, 화요일, 수요일 중에서 조리원 동생을 언제 같이 만나러 갈 수 있는지 이야기하고 있다.
#
# ['내일 디피인 줄도 몰랐는데 인사동에 갔다가 오빠 갤러리에 갈까', '내일 디피인 줄도 몰랐는데 인사동에 갔다가 오빠 갤러리에 가려고', '내일 디피인 줄도 몰랐는데 인사동에 갔다가 오빠 갤러리에 가기로']
# 내일 인사동에 디스플레이(디피)를 하러 가야 돼서 아침에 운동 갔다가 시간 맞으면 잠깐 만나서 오빠 갤러리를 가자고 약속한다.
#
# ['월요일에 끝나는데 임상시험 강의를 신청한 게 있어서 화요일에 만나기로 했다.', '월요일에 끝나는데 임상시험 강의 신청한 게 있어서 화요일에 내려간다고', '월요일에 끝나는데 임상시험 강의 신청한 게 있어서 화요일에 내려간다.']
# 집이 월요일에 끝나지만 화요일에 임상 시험 강의를 신청한 게 있어 화요일에 집에 내려간다.
#
# ['여수에 가봤는데 볼 게 없는 것 같다고 하자 순천도 1박이면 된다고', '여수에 가봤는데 볼 게 없는 것 같다고 하자 순천이나 전주, 광주도', '여수에 볼 게 없는 것 같고 가족들이랑 갔을 때 볼 게 많지는']
# 여수로 여행 갔을 때 볼 게 없던 것과 다른 여행 갈만한 도시에 대해 이야기한다.
#
# ['언제 출발할지에 대해서 이야기하고 있다.', '언제 출발할지에 대해 이야기하며 같이 가자고 하고 있다.', '언제 출발할지에 대해 이야기하며 같이 가자고 하고 있다.']
# 오늘 9시에 약속을 했는데 대화자는 본관 지하에서 먼저 김밥을 사기로 하고 3층에서 대화 상대자를 만나서 같이 가기로 한다.
#
# ['제주도 안 들어가고 우도에 가서 숙소에 짱박히거나 카페에 짱', '제주도 안 들어가고 우도에 가서 숙소에 짱박히거나 카페에 박힐', '제주도 안 들어가고 우도에 가서 숙소에 짱박히거나 카페에 박히']
# 우도가 너무 예뻐서 제주도에 안 들어가고 우도에서 계속 머물겠다는 얘기를 하고 있다.
#
# ['한성대 안 가고 미금에서 고등학교 애들 만나고 있으니 술 많이 먹지 말고', '한성대 안 가고 미금에서 고등학교 애들 만나고 있으니 술 많이 먹지 말', '한성대 안 가고 미금에서 고등학교 애들 만나고 있다고 해서 10시 출발한다고 했다.']
# 미금에서 고등학교 친구들 만나고 10시에 출발한다고 말한다.
#
# ['배고파서 시내버스를 타고 가서 같이 닭갈비를 먹기로 했다.', '배고파서 시내버스를 타고 가면 성심병원쯤에 내릴 수도 있으니 같이', '배고파서 시내버스를 타고 가면 성심병원쯤에 내릴 수도 있어서 같이']
# 배고파서 같이 닭갈비를 먹기로 했다.
#
# ['내일 12시까지 안산에서 놀기로 했다.', '내일 12시까지 안산에서 놀기로 했다.', '내일 12시까지 안산에서 놀기로 했다.']
# 내일 오전 안산에서 놀기 위해 12시에 만나기로 약속한다.
#
# ['계획을 다 짜두니까 든든하고 여행지만 슥 둘러보면 되고 마늘빵과', '계획을 다 짜두니까 든든하고 여행지만 슥 둘러보면 되고 마늘빵도', '계획을 다 짜두니까 든든하고 여행지만 슥 둘러보면 되고 마늘빵이']
# 여행 계획을 다 짜놓으니 마음이 든든하다.
#
# ['엄마가 언제 미국에 갈지 날짜를 정하라고 해서 갈지 안 갈지도 못 정했다고', '엄마가 언제 미국에 갈지 날짜를 정하라고 해서 갈지 안 갈지도 못 정했다.', '엄마가 언제 미국에 갈지 날짜를 정하라고 해서 갈지 안 갈지도 못 정했는데']
# 취업하면 더 가기 힘드니까 엄마가 미국 갔다 오라고 했다.
#
# ['오늘 3시에 범계역에서 만나기로 했다.', '오늘 3시에 범계역에서 만나기로 했다.', '오늘 3시에 범계역에서 만나기로 했다.']
# 오늘 3시에 범계역에서 만나기로 약속하고 출발한다고 알린다.
#
# ['추석에 이모와 가족이랑 제주도에 가기로 했다.', '추석에 이모와 가족이랑 제주도에 가기로 했다.', '추석에 이모와 가족이랑 제주도에 가기로 했다.']
# 추석에 이모와 가족과 제주도 가기로 했다.
#
# ['면접을 보러 가는데 건대입구에서 7호선을 갈아타고 뚝섬 유', '면접을 보러 가는데 건대입구에서 7호선으로 갈아타고 뚝섬 유', '면접을 보러 가는데 늦었지만 건대 입구에서 7호선을 갈아타고 뚝']
# 면접이 잘 안될 경우 공부를 하겠다고 이야기하고 있다.
#
# ['회를 사서 집에 가려고 한다.', '회를 찾아서 집에 가는데 회사에서 회를 사는데 오래 걸린다.', '회를 사서 집에 가려고 한다.']
# 회를 먹고 싶어서 포장해서 가지고 오는 것이 너무 기대된다는 것에 대해 이야기한다.
#
# ['일요일에 시간이 안 되면 점심 먹고 영천으로 가기로 했다.', '일요일에 시간이 안 되면 점심 먹고 영천으로 가자고 한다.', '일요일에 시간이 안 되면 점심 먹고 영천으로 가자고 한다.']
# 일요일에 약속이 없으니 시계를 들고 오라고 했다.
#
# ['8월 1일에 회사 건물에 대고 무국적에 가자고 한다.', '8월 1일에 회사 건물에 대고 무국적에 가기로 했다.', '8월 1일에 회사 건물에 대고 무국적에 가기로 했다.']
# 원래 예정대로 8월 1일에 내차로 뭇국적 식당(뭇국적)에 가자는 이야기를 하고 있다.
#
# ['누구누구가 모였냐며 이에 대해 이야기하고 있다.', '누구누구가 모였냐며 이에 대해 이야기하고 있다.', '누구누구가 모였는지 이야기하고 옷 가게 일을 하는 형이라고 하고 다른 형아']
# 노원 모임에 누가 왔는지 물어보고 있다.
#
# ['여서시 이십분까지 오라고 하였다.', '여서시 이십분까지 오라고 하였다.', '여서시 이십분까지 오라고 하였다.']
# 파출소에서 6시 20분에 만나서 함께 가기로 했다.
#
# ['코로나 때문에 장사가 안돼서 호텔이나 펜션에서 싸게 나와서 여행을', '코로나 때문에 장사가 안돼서 호텔이나 펜션이 싸게 나와서 여행을', '코로나 때문에 장사가 안돼서 호텔이나 펜션에서 싸게 나와서 여행']
# 코로나 상황 속에서 답답했던 마음을 여행으로 풀려고 하고 있다.
#
# ['북해도 여행을 다녀온다고 하니 회사에서 전화가 온다고 해서 부럽다고 한다.', '잘 놀다 오라며 여행 다녀오겠다고 하자 회사보다 백배 천배라고 한다.', '잘 놀다 오라며 여행 다녀오겠다고 하자 회사보다 백배 천배라고 하며']
# 여행 가면 재밌을 것이니 조심히 다녀오라고 대화한다.
#
# ['저녁에 대게를 먹고 싶다고 해서 숙소 근처에 맛있는 곳을 찾아서 먹', '저녁에 대게를 먹고 싶어서 숙소 근처에 맛있는 곳을 찾아서 먹기로', '저녁에 대게를 먹고 싶어서 숙소 근처에 맛있는 곳을 찾아서 먹자고']
# 저녁으로 숙소 근처에서 맛있는 데를 찾아서 대게를 먹을 것이다.
#
# ['8월 12일에 베트남 돈 환전을 했다.', '8월 12일에 베트남 돈 환전을 했다.', '8월 12일에 베트남 돈 환전을 했다.']
# 위비에서 문자가 와서 베트남의 돈을 환전한 것을 알았다고 한다.
#
# ['내일 연남동에 가서 맛있는 것을 사주겠다고 한다.', '내일 연남동에 가서 맛있는 것을 사주겠다고 한다.', '내일 연남동에 가서 맛있는 것을 사주겠다고 한다.']
# 동생이 언니에게 두 달 빨리 축하해 주는 생일 밥으로 맛있는 거 사줄 테니 연남동으로 오라고 했다.
#
# ['햄버거를 먹으러 가기로 하고 맥도날드(맥날)에 가', '햄버거를 먹으러 가기로 하고 맥도날드(맥날)에 갈', '햄버거를 먹으러 맥도날드(맥날)로 가기로 했다.']
# 햄버거를 먹기로 해서 맥도날드 앞에서 아이스크림을 먹고 있기로 했다.
#
# ['내일 연차라서 7시에 끝나는데 술을 마실지 저녁을 함께 먹을지', '내일 연차라서 만나서 술을 마실지 저녁을 같이 먹을지에 대해 이야기', '내일 연차라서 7시에 끝나는데 술을 마실지 저녁을 같이 먹자고']
# 내일 오면 11시 10분 도착이라 저녁을 먹으면서 술 먹고 싶으면 시키려 한다.
#
# ['다음 주 화요일이나 수요일에 만나서 서브웨이(섭웨이)를 먹기로', '다음 주 화요일이나 수요일에 만나서 서브웨이를 먹기로 했다.', '다음 주 화요일이나 수요일에 만나서 서브웨이를 먹기로 했다.']
# 다음 주에 만나 서브웨이를 먹으러 화요일이나 수요일에 만나자고 한다.
#
# ['연어를 샀는데 그쪽에서 다른 사람 거랑 바뀌어서 왔는데 그냥 먹으', '연어를 샀는데 다른 사람이랑 바뀌어서 다른 사람이랑 먹으라고 해서 먹고 원래', '연어를 샀는데 그쪽에서 다른 사람 거랑 바뀌어서 왔다.']
# 다른 사람의 것과 바뀌어서 온 연어를 그냥 먹으라고 했다.
#
# ['검색대에서 버스를 탔는데 살짝 지연인 것 같다고 하자 다행이라며 오면 해물', '검색대에서 버스를 탔는데 지연이 된 것 같다고 하자 다행이라고 한다.', '검색대에서 버스를 탔는데 살짝 지연인 것 같다고 한다.']
# 지연이 돼서 버스 타고 가고 있다고 하자 슬슬 준비해서 나가겠다고 하고 있다.
#
# ['빨리 먹고 싶다고 하자 자기도 빨리 먹고 싶다며 만두만두 샤오롱바', '빨리 먹고 싶다고 하자 자기도 빨리 먹고 싶다며 만두만두 샤오롱 바', '빨리 먹고 싶다고 하자 자기도 빨리 먹고 싶다며 만두만두와 샤오롱']
# 빨리 대만 음식이 먹고 싶다고 하자 자기도 그렇다며 빨리 가고 싶다고 말한다.
#
# ['드레스 구경하기로 간 곳은 두 곳만 가도 되니까 과외를 안 빼', '드레스 구경하기로 간 곳은 두 곳만 가도 되니까 과외 안 빼도', '드레스 구경하기로 간 곳은 두 곳만 가도 되고 과외를 안 빼도']
# 드레스 투어를 두 곳만 가면 되는 줄 알아서 과외는 빼지 않아도 된다고 생각했는데 알고 보니 세 곳이었다.
#
# ['대만이 비싸서 전화할 수 있는지 물어보고 있다.', '대만이 비싸서 전화할 수 있는지 물어본다.', '대만이 비싸서 전화할 수 있는지 물어보고 있다.']
# 전화가 가능한지 묻고 대만도 비싸서 가지 않았다고 한다.
#
# ['내일 강릉 당일치기로 갔다가 오빠네서 같이 자기로 했다.', '내일 강릉 당일치기로 갔다가 오빠네서 같이 자기로 했다.', '강릉에 당일치기로 갔다가 오빠네서 자는 거라며 내일 왕가리에 가']
# 내일 강릉에 당일치기 갔다가 오빠네서 자려고 한다.
#
# ['토요일에 종합운동장에서 만나서 치킨을 먹기로 했다.', '언니와 동생이 토요일에 종합운동장에서 만나서 치킨을 먹기로 한다.', '토요일에 종합운동장에서 만나서 치킨을 먹기로 했다.']
# 공연을 보는 언니와 같이 식사를 하자고 약속과 장소를 정하고 있다.
#
# ['퇴사 날이라서 토요일에 보장이 안된다고 한다.', '퇴사 날이라서 토요일에 보장이 안 된다.', '다음 주 토요일에 퇴사하는 오빠가 다른 날로 옮길 수 있는지 확인한다.']
# 다음 주 토요일(토욜) 약속을 다른 날로 옮길 수 있나 해서 다른 날이 되는지 물어보았다.
#
# ['토요일에 이모네는 일요일에 낮에 출발해서 저녁에 밥을 먹을 것 같다.', '토요일에 이모네는 일요일에 낮에 출발해서 저녁에 밥 먹을 것 같다.', '토요일에 이모네는 일요일에 낮에 출발해서 저녁에 밥 먹을 것 같다고']
# 이모네는 일요일 낮에 출발하니까 먼 길 오시는데 토요일에 오면 같이 밥 먹자고 한다.
#
# ['내일 집에서 운동을 하고 일요일에 데리러 가기로 했다.', '내일 집에서 운동을 하고 일요일에 데리러 가기로 했다.', '일요일에 놀다가 집에서 드라마도 보고 일요일에 데리러 가기로 했다.']
# 토요일에는 각자 쉬고 일요일에 같이 만나서 놀기로 했다.
#
# ['해운대가 조용한절인 줄 알았는데 완전 관광지였고 바다에 절이 있어서', '지금 용궁사에 왔는데 바다에 절이 있어서 조용한 절인 줄 알았는데', '해운대에 있는 용궁사에 왔는데 조용한 절인 줄 알았는데 완전 관광지']
# 용궁사가 사람도 많고 바다에 절이 있어서 신기하다.
#
# ['개나리 사진을 찍었던 루트로 간다고 하자 9시에 병원에 간다고 한다.', '개나리 사진 찍었던 루트로 가야겠다고 하자 늦잠 자도 된다고 한다.', '개나리 사진을 찍었던 루트로 가려고 한다.']
# 개나리 사진 찍었던 루트로 가자며 뚝섬 유원지에서 쭉 걸어서 서울숲 가서 구경하다가 카페로 가자고 한다.
#
# ['언니 기준은 내일이고 월요일 기준은 7월 17일이다.', '언니 기준은 내일이고 월요일 기준은 오늘이다.', '언니 기준은 내일이고 월요일 기준은 오늘이다.']
# 7월 17일이 주된 날(메인데이)로 수족관을 가는 날이다.
#
# ['저녁에 집에서 티브이(티비)를 보고 저녁에 매운 걸 사 가', '저녁에 집에서 티브이(티비)를 보고 저녁에 매운 것을 사 가', '저녁에 집에서 티브이(티비)를 보고 저녁에 매운 것을 사서']
# 상대방과 만나기 위해서 먼저 집에 가서 티브이 보면서 혼자 놀고 있으라고 한다.
#
# ['감기 걸린 건 아니고 날씨가 좋아서 다행이고 새벽에 조식을 준다고 해서 엄마가', '감기 걸린 건 아니고 날씨가 좋아서 다행이고 새벽에 조식 준다고 해서 눈', '감기 걸린 건 아니고 날씨가 좋아서 다행이고 오늘도 날씨가 맑고 조식을 준다고']
# 조식을 준다고 해서 일찍 일어났는데 언니는 아직 자고 오늘도 날씨가 좋다.
#
# ['선생님들이 추워지기 전에 놀러 가자고 하자 갈 거면 미리 말해야 한다고', '선생님들이 추워지기 전에 놀러 가자고 하자 갈 거면 미리 말해야 한', '선생님들이 추워지기 전에 놀러 가자고 하자 갈 거면 미리 말해야 하고']
# 선생님(쌤)들에게 추워지기 전에 놀러 가자고 하자, 갈 거면 미리 돈 모아야 하며 좋다고 한다.
#
# ['오늘 피시방에 사람이 별로 없어서 로그인해서 자리 잡아놓기로 했다.', '오늘 피시방에 사람이 별로 없어서 로그인해서 자리 잡아놓기로 했다.', '오늘 피시방에 사람이 별로 없어서 로그인해서 자리 잡아 놓는다고 한다.']
# 언니가 동생에게 미리 피시방 자리를 잡아서 로그인을 해달라고 부탁한다.
#
# ['카페에 갔다가 맛있는 걸 먹고 나중에 샐 생각이라고 한다.', '카페에 갔다가 맛있는 걸 먹고 나중에 샐 생각이라고 하자 잘 맞는다고 한다.', '카페에 갔다가 맛있는 거 먹고 나중에 샐 생각이라고 한다.']
# 카페 갔다가 맛있는 거 먹고 할 거 생기면 찾아서 하기로 한 것이 잘 맞아 다행이다.
#
# ['엄마가 코로나 때문에 안 간다며 텐트를 가지고 자전거나 타러 가자고', '엄마가 코로나 때문에 안 간다며 텐트를 가지고 자전거나 타러 가라고', '엄마가 코로나 때문에 텐트를 가지고 자전거나 타러 가자고 한다.']
# 엄마가 코로나 때문에 텐트를 갖고 자전거나 타러 가자고 짜증을 내신다.
#
# ['내일 지인의 결혼식에 가기 귀찮으니 가지 말고 오늘 내려오라고 한다.', '가기 귀찮으니 가지 말고 오늘 내려오라고 하자 금요일에 누구 집에서 자라고 한다.', '가기 귀찮으니 가지 말고 오늘 내려오라고 한다.']
# 오늘 내려가고 싶지만 결혼식이 있어서 내일 내려간다.
#
# ['예식장이 식사 최소 인원을 1명도 안 깎아준다며 양아치 같', '예식장이 최소 인원 1명도 안 깎아준다고 해서 양아치 같', '예식장이 식사 최소 인원을 1명도 안 깎아준다고 해서 양아치']
# 예식장에서 식사 보증 인원을 안 깎아 주는데 국가에서 지원을 해줘야 한다.
#
# ['엄마에게 김장을 언제 하는지 물어보라고 하였다.', '엄마한테 김장을 언제 하는지 물어보라고 하였다.', '엄마한테 김장을 언제 하는지 물어보라고 하였고 김장을 언제 하는지 물어보라고']
# 김장을 언제 하는 지 엄마애개 물어보려고한다.
#
# ['오늘 일 생겨서 월요일에 오라고 해서 카페를 팔았는데 장사가 잘', '오늘 일 생겨서 월요일에 오라고 해서 카페를 팔았는데 장사가 안', '오늘 카페를 팔았는데 장사가 잘 안 돼서 팔았다가 다시 팔았다.']
# 카페가 장사가 잘 안돼서 팔았다고 마지막으로 놀러 오라고 해서 가기로 했었는데 일이 생겨서 월요일에 오라고 했다.
#
# ['다음 주(담주) 수요일(수욜) 지나고 몸보신을 시켜준다고', '다음 주(담주) 수요일(수욜) 지나고 몸보신을 시켜주겠다고', '다음 주(담주) 수요일(수욜) 지나고 몸보신을 시켜주기로']
# 다음 주 수요일 지나고 한가해지면 누룽지 백숙을 사달라고 한다.
#
# ['엄마가 오늘 퇴원해서 금요일에 끝나고 갔다가 토요일 저녁 먹기 전에 오면 될 것', '엄마가 오늘 퇴원해서 금요일에 끝나고 갔다가 토요일 저녁을 먹기 전에 오면 될', '엄마가 오늘 퇴원해서 토요일 저녁 먹기 전에 만날 수 있을 것 같다.']
# 엄마 오늘 퇴원해서 만날 수 있을 거 같다.
#
# ['목요일에 필라테스(필테)가 끝나면 8시 50분에 나온다.', '목요일에 필라테스(필테)가 끝나면 8시 50분에 나온다고 한다.', '목요일에 필라테스(필테)가 끝나고 주말에 보기로 한다.']
# 목요일에 필라테스(필테)가 8시 50분에 끝나서 너무 늦으니 주말에 보기로 한다.
#
# ['주말에 속초에 갔다 왔는데 코로나 때문에 사람들이 많아서 못 놀', '주말에 속초에 갔다 왔는데 코로나에 걸려서 가족 친구들이 걱정', '주말에 속초에 갔다 왔는데 코로나에 걸려서 주변인한테']
# 코로나인데 속초에 사람이 많다고 이야기하고 못 나가서 억울하지만 코로나 걸려서 주변에 피해 주는 것보다 낫다고 한다.
#
# ['아고다에서 비행기 스케줄 변경 서류를 달라고 하면 그냥 알았다고 하고 진행', '아고다에서 비행기 스케줄 변경 서류 달라고 하면 알았다고 하고 진행 안 하면', '아고다에서 비행기 스케줄 변경 서류 달라고 하면 그냥 알았다고 하고 진행 안']
# 호텔에서 취소가 안된다고 했다고 아고다에서 연락이 왔다고 이야기하고 있다.
#
# ['다음 달쯤 갈 거 같은데 부산에 가서 바다를 실컷 보고 오겠다고 한다.', '다음 달쯤 갈 거 같은데 부산에 가서 바다를 실컷 보고 오겠다.', '다음 달쯤에 부산에 가서 바다를 실컷 보고 오기로 했다.']
# 부산을 다음 달쯤 갈 거 같고 부산바다는 어떤 느낌일지 궁금해서 빨리 보고 싶다.
#
# ['상하이로 해외여행을 갔는데 미세먼지가 심했지만 생각보다 사람이 안 바글거', '상하이로 해외여행을 갔는데 미세먼지가 심했지만 생각보다 사람이 안 와서 좋았다.', '상하이로 해외여행을 갔는데 미세먼지가 심했지만 생각보다 사람이 안 보였다고 한다.']
# 미세먼지가 심했지만 너무 좋았어서 상하이에 또 가고 싶다.
#
# ['제주도 여행을 갈 수 있냐며 스위스와 이탈리아를 갈지 스위스 항공에서 비행기', '제주도 여행을 갈 수 있냐며 스위스와 이탈리아를 갈지 스위스 항공에 들어가서', '12월에 결혼 준비를 위해 제주도 여행을 갈 수 있는지 물어보고 있다.']
# 신혼여행으로 스위스랑 이탈리아 가는데 스위스에서 이탈리아 가는 것이 비행기로 가거나 기차인데 기차는 너무 오래 걸려 비추천이다.
#
# ['일어나서 과자를 먹어서 배가 안 고프다고 하니 알아서 먹고 가겠다고 한다.', '일어나서 과자 먹어서 배가 안 고프다고 하니 알아서 먹고 가겠다고 한다.', '일어나서 과자를 먹어서 배가 안 고프다고 하니 알아서 먹고 간다고 한다.']
# 일어나서 과자를 먹었더니 배가 안 고파서 점심을 세 시에 먹는다고 말한다.
#
# ['블로그 후기가 좋은 곳에 대해 이야기하며 셋이 만나기 좋은 곳으로 정해도 될 것', '블로그 후기가 좋은 곳에 대해 이야기하며 셋이 만나기 좋은 곳으로 정해도 될 거', '블로그 후기가 좋은 곳에 대해 이야기하며 셋이 만나기 좋은 곳으로 정하면 될 것']
# 여기 블로그 후기도 좋다고 하자 훠궈 맛이 다 거기서 거기니 셋이 만나기 좋은 곳으로 정해도 될 거 같다.
#
# ['코타키나발루, 세부/ 사이판, 괌, 괌을', '언니랑 코타키나발루, 세부/ 사이판, 괌을 갔', '코타키나발루, 세부/ 사이판, 괌, 괌,']
# 여행가기에 좋은 국가를 선정하고 있다.
#
# ['열시 조금 넘어서 잠실에서 와인을 먹으러 출발한다.', '열시 조금 넘어서 잠실에서 와인을 먹으러 간다.', '열시 조금 넘어서 잠실에서 와인을 먹으러 간다고 한다.']
# 열 시 넘어서 와인 먹는 자리에 도착 예정이다.
#
# ['환갑잔치를 그렇게 요란하게 하는 사람도 처음 봤는데 요즘 환갑은 누가', '환갑잔치를 그렇게 요란하게 하는 사람도 처음 봤고 요즘 환갑은 누가', '환갑잔치를 그렇게 요란하게 하는 사람도 처음 봤는데 요즘 환갑잔치를']
# 환갑잔치 때 샴페인을 상온에 둬서 폭발하는 사건이 있었다.
#
# ['오늘 엄마와 선인장 마을과 이토헤우에 갔다가 월정리에', '오늘 엄마랑 선인장 마을과 이토헤우에 갔다가 월정리에', '오늘 엄마랑 선인장 마을과 이토헤우에 갔다가 비가 많이 와서']
# 엄마랑 선인장 마을이랑 이토헤우 다녀오고 월정리 갔다가 비가 많이 오고 사람도 많아서 그냥 숙소로 갔다는 이야기를 한다.
#
# ['오늘 둘이 닭칼국수를 먹으러 가기로 했다.', '오늘 둘이 닭칼국수를 먹으러 가기로 하고 화순에 가면 물어보고', '오늘 둘이 닭칼국수를 먹으러 가기로 했다.']
# 오늘 둘이서 닭칼국수를 먹기로 한다.
#
# ['우체국에 갔다가 석계에 가서 먹고 동네에 와서 스타벅스(스벅)에', '우체국에 갔다가 석계에 가서 먹고 동네에 와서 스타벅스(스벅)를', '우체국에 갔다가 석계에 가서 먹고 동네에 와서 스타벅스(스벅)을']
# 내일 만나기 전 할 일과 우체국에서 만난 후 동선에 대해 이야기한다.
#
# ['9월에 아르바이트(알바)를 그만하면 기말고사(기말)', '9월에 아르바이트(알바)를 그만하면 주말에 어디 놀러 가자고 한다.', '9월에 아르바이트(알바)를 그만하면 기말고사(기말)가']
# 9월에 아르바이트(알바)를 그만두면 기말고사 전에 둘이서 주말에 놀러 가자고 한다.
#
# ['갑자기 여행 가서 모르는 곳 돌아다니는 느낌이 팍 왔는데 코로나 때문에 더 심', '갑자기 여행 가서 모르는 곳 돌아다니는 느낌이 팍 와서 코로나 느낌이다.', '갑자기 여행 가서 모르는 곳 돌아다니는 느낌이 팍 왔다.']
# 여행에 가고 싶다고 하며 트래블러를 보고 상하이나 파리를 돌아다닐 때 느낌이 떠올랐다고 한다.
#
# ['목요일에 대리 뛰고 스터디 카페 청소해놓고 8시부터 12시까지 대리', '목요일 8시부터 12시까지 스터디 카페 청소를 하고 투표를 하자고 한다.', '목요일에 대리 뛰고 스터디 카페 청소해놓고 8시부터 12시까지 대']
# 사전 투표 날짜에 대해 이야기하고 스터디 카페를 청소를 언제 하고 떠날지 이야기한다.
#
# ['39구역에 누웠는데 감기에 걸려서 빨리 옷을 입으라고 한다.', '39구역에 누워있는데 감기 걸리니 빨리 옷을 입으라고 한다.', '39구역에 누워있는데 감기에 걸리니 빨리 옷을 입으라고 한다.']
# 상대 짐을 들고나갈 힘이 없어서 누워있다가 만나러 나왔다.
#
# ['마감은 빠르지만 사람들이 너무 빠르다고 한다.', '마감은 빠르지만 사람들이 너무 빠르다.', '마감은 빠르지만 사람들이 너무 빠르다.']
# 마감이라고 하자 11시도 있다며 도전해야 한다고 한다.
#
# ['원래 수영장에서 수영복 입고 놀고 안방 비치에 가서 사진 찍어야 해서 옷을 갈아', '원래 수영장에서 수영복 입고 놀고 안방 비치에 가서 사진 찍어야 하니까 옷을 갈아', '원래 수영장에서 수영복 입고 놀고 사진 찍어야 해서 옷을 갈아입고 가서 보']
# 안방 비치로 옷을 갈아입고 가서 타려고 했는데 흙탕물을 먹을 수도 있고 극단적이다.
#
# ['다음 주 토요일에 대천에 머드 축제를 가는데 친구들끼리 가야 재미있', '다음 주 토요일에 대천에 머드 축제를 가는데 친구들끼리 가야 재밌', '다음 주 토요일에 대천에 머드 축제를 가는데 친구들끼리 가면 재미있']
# 다음 주에 내려가는데 토요일에 대천 머드축제를 가며 일정이 뮤직뱅크(뮤뱅)와 겹쳤다고 말하고 있다.
#
# ['오늘 7시 15분까지 갈 수 있을 것 같다고 하자 먼저 보면 더 좋다고 한다.', '오늘 7시 15분까지 갈 수 있을 것 같다고 하자 먼저 보면 더 좋다고 한다.', '오늘 7시 15분까지 갈 수 있을 것 같다고 하자 먼저 보면 더 좋겠다고 한다.']
# 언니를 먼저 만나기 위해 최대한 칼퇴근해보려고 한다.
#
# ['오빠도 안 가고 싶다고 언니랑 둘이 타고 오라고 해서 내일 엄마한테 봐달라고', '오빠도 안 가고 싶다고 언니랑 둘이 타고 오라고 했다.', '오빠도 안 가고 싶다고 언니랑 둘이 타고 오라고 하였다.']
# 오빠도 안 가고 싶으니 둘이 타고 오라는데 그 티켓을 많이 줄지도 모르니까 친구 두 명 더 갈 사람 없냐고 한다.
#
# ['날이 좋으니 어디든 가고 싶고 돌아다니고 싶어서 익선동에 가자고', '날이 좋으니 어디든 가고 싶고 돌아다니고 싶어서 익선동에 가기로', '날이 좋아서 어디든 가고 싶고 돌아다니고 싶어서 익선동에 가자고']
# 요즘 익선동에 식물들이 파릇파릇해서 너무 이쁘다며 다음은 익선동을 가자고 한다.
#
# ['학교로 바지를 가져다주러 가기로 했다.', '학교로 바지를 가져다주러 가기로 했다.', '학교로 바지를 가져다주러 가기로 했다.']
# 2시부터 4시까지 시간이 비는 사람에게 3시에 수업이 끝나는 사람이 바지를 갖다 주기 위해 한양대역으로 간다.
#
# ['오빠가 오늘은 회사로 오지 말고 버스정류장에서 만나자고 한다.', '오빠가 오늘은 회사로 오지 말고 버스정류장에서 만나기로 했다.', '오빠가 오늘은 회사로 오지 말고 버스정류장에서 만나자고 한다.']
# 오늘은 회사로 오지 말고 버스 정류장에서 만나자고 하자 이미 다 왔다고 한다.
#
# ['하루 만에 비행기 예약을 다 끝냈는데 비행기 값이 너무 비싸서 못', '하루 만에 비행기 예약을 다 끝냈는데 비행기 값 때문에 못 가겠다.', '하루 만에 비행기 예약을 다 끝냈는데 비행기 값 때문에 세부 간다고 한다.']
# 세부행 항공권이 40만 원이었는데 얼마 안 남아서 싸진 건지 지인은 왕복 30만 원에 샀다.
#
# ['호주에 가서 뭐 할지 스케줄을 정리하고 전자비자 신청을 하고 있다.', '호주에 가서 뭐 할지 스케줄을 정리하고 전자비자 신청 중인데 한 달 무', '호주에 가서 뭐 할지 스케줄을 정리하고 전자비자 신청 중이다.']
# 호주 스케줄을 공유해달라고 하고 전자 비자가 필요하다고 하고 내년에 해야겠다고 한다.
#
# ['유럽에 언니가 많이 갔는데 어렸을 때 다 좋았다고 한다.', '유럽에 언니가 많이 갔는데 어렸을 때라 잘 기억이 안 난다.', '유럽에 언니가 많이 갔는데 어렸을 때라 잘 기억이 안 난다고 한다.']
# 언니는 어렸을 때 유럽을 갔지만 기억은 잘 안 난다고 하고 다 좋아서 또 가고 싶다고 한다.
#
# ['유유자적하게 있고 싶어서 양양에 1박 2일로 가려고 한다.', '유유자적하게 있고 싶어서 양양에 1박 2일로 가고 싶다.', '유유자적하게 있고 싶어서 양양에 1박 2일로 가자고 한다.']
# 여기는 강원도 양양으로 1박 2일만 해도 되지만 나는 유유자적하게 있고 싶고 앞의 바다에 아무도 없고 코로나에 아주 좋아 보인다.
#
# ['지하철을 타고 반월당에 다 와가면 연락하기로 했다.', '반월당에서 내려서 지하철을 타고 다 와가면 연락하기로 했다.', '반월당에서 내려서 지하철을 타고 다 와가면 연락하겠다고 한다.']
# 반월당에서 내려야 하는데, 분수대는 모른다고 하니까 일단 지하철(쟈철) 타고 다 와가면 연락하겠다고 이야기한다.
#
# ['입장 마감은 7시이고 8시까지 해서 저녁 먹고 보러 가면 될 것 같다.', '입장 마감은 7시이고 8시까지 해서 저녁을 먹고 보러 가려고 한다.', '입장 마감은 7시이고 8시까지 해서 저녁 먹고 보러 가기로 했다.']
# 입장마감은 7시고 8시까지 해서 저녁을 빠르게 먹고 보러 가자고 하지만 저녁을 먹기 전에 가야 할 것 같아 한다.
#
# ['내일 몇 시에 만날지 정하고 있다.', '내일 몇 시에 만날지 정하고 있다.', '내일 몇 시에 만날지 정하고 있다.']
# 내일 몇 시에 만나는 것은 두  사람 모두 상관이 없고 을지로에 있는 우래옥을 가기로 한다.
#
# ['역곡역인데 스타벅스(스벅) 열 시까지라서 투썸플레이', '역곡역 스타벅스(스벅)에서 만나기로 했다.', '역곡역 스타벅스(스벅)에서 만나기로 했다.']
# 늦게까지 하는 투썸 플레이스 카페에서 지인과 만나기로 했다.
#
# ['롯데몰에 거의 다 왔고 차가 엄청 많아서 3층에 올라왔다.', '롯데몰에 거의 다 왔는데 차가 엄청 많아서 3층에 올라왔다.', '롯데몰에 거의 다 왔는데 차가 엄청 많아서 지금 3층에 올라왔다고 한다.']
# 주차장에 차가 많아서 계속 올라가고 있다고 하자 대화 상대도 올라가겠다고 한다.
#
# ['술 한잔할 거면 저녁도 좋고 간단히 할 거면 점심도 좋고 맛있는', '술 한잔할 거면 저녁도 좋고 간단히 할 거면 점심도 좋으니', '술 한잔할 거면 저녁도 좋고 간단히 할 거면 점심을 먹자고']
# 다음날 때문에 그날 다시 옥천 가야 해서 술은 안된다.
#
# ['스타벅스에 가기로 하고 카페에 간다고 한다.', '스타벅스에 가기로 하고 카페에 간다고 한다.', '스타벅스에 가기로 하고 카페에 간다고 한다.']
# 너무 비싸지만 그래도 괜찮으니 스타벅스에 가기로 했다.
#
# ['대학교 친구들이랑 제주도 비행기 예약을 했다.', '대학교 친구들이랑 제주도 비행기 예약을 했다.', '대학교 친구들이랑 제주도 비행기 예약을 했다.']
# 대학교 친구들과 가려고 제주도행 비행기를 예약했으니 소원성취했다.
#
# ['순천에서 하동까지 기차로 20분이고 겨울이라 마루는 추울 것 같', '순천에서 하동까지 기차로 20분인데 겨울이라 마루는 추울 것 같', '겨울이라 마루는 추울 것 같지만 순천에서 하동까지 기차로 20분']
# 순천에서 하동까지 기차로 20분밖에 안 걸리고 하동이 예뻐서 가기로 한다.
#
# ['다음 주(담주)에 결혼하는 언니와 수요일에 맛있는 것을 먹으러 가', '다음 주(담주)에 결혼하는 언니와 수요일에 맛있는 거 먹으러 가', '언니와 동생이 다음 주에 결혼하는 것에 대해 이야기하고 있다.']
# 다음 주에 결혼을 한다고 그동안 연락 없어서 미안하다고 만나자고 한다.
#
# ['차라리 잘 거면 애들이 없는 게 편하다고 하자 그럼 내일 원래대로 차이나타운', '차라리 잘 거면 애들이 없는 게 편할 거라고 하자 그럼 내일 원래대로 차이나', '차라리 잘 거면 애들이 없는 게 편할 것 같고 손질은 어차피 해']
# 손질을 해 본 적이 없어 못하기 때문에 내일 점심에 차이나타운에 가기로 하였다.
#
# ['요즈음(요즘)에 조식은 개방하지 않는다.', '요즈음(요즘)에 조식은 개방하지 않는다.', '요즈음(요즘)에 조식은 개방하지 않고 조식만 개방한다.']
# 조식 어디가 좋을까라고 하자, 아마 조식 개방안 할 것이고 주는 데는 주더라고 한다.
#
# ['이번 주 토요일에 안 놀면 후회하니까 만나지 말자고 한다.', '이번 주 토요일에 안 놀면 후회하니 만나지 말자고 한다.', '이번 주 토요일에 안 놀면 후회하니 만나지 말라고 한다.']
# 이번 주 토요일에 상황을 보면서 가기로 하지만 애매하면 만나지 말자고 한다.
#
# ['매장 점장님이 결혼식에 갔는데 너무 밝아서 옷을 뭘 입어야 할지 모르겠다.', '결혼식 때 어떤 옷을 입어야 할지 이야기하고 매장 점장님이 하객 룩스트', '매장 점장님이 결혼식에 갔는데 너무 밝아서 옷을 뭘 입어야 할지 고민하고']
# 매점 점장님 결혼식에 어떤 옷을 입고 가야 하는지 고민하고 있다.
#
# ['수원 씨지브이(cgv)는 아직 주말 시간이 안 나와서 수원역에서', '수원 시지브이(CGV)는 아직 주말 시간이 안 나와서 수원역에서 만나', '수원 씨지브이(CGV)는 아직 주말 시간이 안 나왔고 수원 씨지']
# 수원역 씨지브이(CGV) 주말 시간표가 나오는 대로 약속 시간을 정하려고 한다.
#
# ['대전 살면서 한 번도 킹스타에 가본 적이 없으니 킹스타에 가자고', '대전 살면서 한 번도 킹스타에 가본 적이 없으니 킹스타를 가자고', '대전 살면서 한 번도 킹스타에 가본 적이 없으니 가자고 한다.']
# 대전에 살면서 한 번도 킹스타에 가본 적 없는 사람에게 킹스타에 같이 가자고 제안한다.
#
# ['내일 몇 시에 만날지에 대해 이야기하고 있다.', '내일 몇 시에 만날지에 대해 이야기하고 있다.', '내일 몇 시에 만날지에 대해 이야기하고 있다.']
# 내일 낮에 만나서 광안리를 보러 가기로 했다.
#
# ['오빠는 벌써 들어왔고 몇 시에 도착하는지 물어보고 있다.', '오빠는 벌써 들어왔고 몇 시에 도착하는지 물어보고 있다.', '오빠는 벌써 들어왔고 몇 시에 도착하는지 물어보고 있다.']
# 12시 안에 도착할 예정이다.
#
# ['너 덕분에 사귀게 돼서 다음 주(담 주)에 돈대길 가자고', '너 덕분에 사귀게 돼서 다음 주에 돈대길 가자고 한다.', '너 덕분에 사귀게 되었다며 다음 주에 돈대길 가자고 한다.']
# 다음 주에 돈대길 갈 생각에 설렌다고 하였다.
#
# ['집에 가서 같이 디저트를 먹기로 했다.', '집에 가서 같이 디저트를 먹기로 했다.', '집에 가서 같이 디저트를 먹기로 했다.']
# 디저트를 먹자고 하고 집에 가서 먹자고 한다.
#
# ['중간고사 기간이 끝나면 이자카야에 가서 양꼬치를 먹기로 했다.', '중간고사 기간이 끝나면 이자카야에 가서 양꼬치를 먹기로 했다.', '중간고사 기간이 끝나면 이자카야에 가서 술을 마시기로 했다.']
# 중간고사 끝나면 술 먹으러 일단 코다차야에 가기로 한다.
#
# ['면접이 끝나고도 시간이 촉박할 것 같아서 주말에 안 본다고 이야기하고 있다.', '면접이 끝나고도 시간이 촉박할 것 같아서 주말에 안 본다고 한다.', '면접이 끝나고도 시간이 촉박할 것 같아서 주말에 안 본다고 말한다.']
# 면접 끝나고도 시험을 준비하는 상대를 방해하는 것 같아서 주말에 안 봐도 괜찮다고 이야기하고 있다.
#
# ['기념품과 배낭을 사면 어깨가 빠질까 봐 걱정된다.', '기념품으로 맥주 같은 걸 사면 어깨가 빠질까 봐 걱정되지만 배낭을', '기념품과 배낭을 사면 어깨가 빠질까 봐 걱정된다고 이야기하고 있다.']
# 여행을 갈 때 어떤 가방을 가지고 갈지에 대해 토론한다.
#
# ['파리바게뜨에서 만나기로 했다.', '파리바게뜨에서 만나기로 했다.', '파리바게뜨에서 만나기로 했다.']
# 50분에 밑에서 보기로 했다.
#
# ['엄마 아빠가 세뱃돈을 받아서 십만 원을 벌었다.', '엄마 아빠가 세뱃돈을 받아서 십만 원을 벌었다.', '엄마 아빠가 세뱃돈을 받아서 십만 원을 벌었다.']
# 엄마 아빠에게 세배하고 10만 원 세뱃돈을 받았다고 하니 부럽다고 한다.
#
# ['토요일에 엄마 공항에 데려다주고 6시쯤에 출발할 때 전화하기로 했다.', '토요일에 엄마 공항에 데려다주고 6시쯤 출발할 때 전화한다고 한다.', '토요일에 엄마 공항에 데려다주고 6시쯤 출발할 때 전화해서 씻기로 했다.']
# 치킨집에서 일 부탁해서 내일 말고 토요일 저녁 6시로 약속을 다시 잡는다.
#
# ['토요일에 헬스장에 세시쯤 가기로 했다.', '토요일 세시쯤 헬스장에 가기로 했다.', '토요일에 헬스장에 몇 시쯤 갈지 이야기하고 있다.']
# 헬스장에 몇 시에 갈지 이야기하고 세 시쯤 가자고 하고 샤워용품은 같이 쓰면 돼서 안 챙겨도 된다고 한다.
#
# ['오늘 약속이 있어서 다음에 만나기로 했다.', '오늘 약속이 있어서 다음에 만나자고 한다.', '오늘 약속이 있어서 다음에 만나자고 한다.']
# 언니는 오늘 약속이 있어 다음에 만나기로 했다.
#
# ['다음 주에 아르바이트(알바) 끝나고 시간 맞춰 보자고 한다.', '다음 주에 아르바이트(알바) 끝나고 시간을 맞춰 보자고 한다.', '다음 주에 아르바이트(알바) 끝나고 시간 맞춰 보자고 한다.']
# 다음 주 월요일만 병원 때문에 못 가고 아르바이트 끝나고 시간을 맞춰서 같이 보자고 한다.
#
# ['언니가 여행을 가고 싶지만 돈이 없어서 아빠에게 말해서 삿포로라도 갈까', '언니가 여행을 가고 싶지만 돈이 없어서 아빠에게 말해서 삿포로를 갈지', '언니가 여행을 가고 싶지만 돈이 없어서 아빠에게 말해서 삿포로로 갈지']
# 여행을 가고 싶은데 돈이 없어서 아빠에게 말해서 떠날까 고민 중인데 가까운 삿포로에 가려고 한다고 하자 얼어 죽는다고 한다.
#
# ['두 곳 중 어디가 괜찮은지 물어보고 있다.', '두 곳 중 어디가 괜찮은지 물어보고 있다.', '두 곳 중 어디가 괜찮은지 가봐야 하는데 두 번째는 안락한 느낌']
# 첫 번째는 안락한 느낌이었고 두 곳이 느낌이 달랐다.
#
# ['버스에서 내리니까 살 것 같은데 생각보다 일찍 도착했고 약속 시간이 안 늦어서 다행', '생각보다 일찍 도착했는데 약속 시간이 안 늦어서 다행이라고 한다.', '버스에서 내리니까 살 것 같은데 생각보다 일찍 도착했고 약속시간 안 늦어서 다행']
# 약속시간에 늦을까 봐 걱정을 했지만 빨리 도착했다고 이야기한다.
#
# ['인천이 너무 비싸서 군포가 더 아깝고 의정부가 제일 싼데 광주', '인천이 너무 비싸서 군포가 더 아깝고 의정부가 제일 싼데 광', '인천이 너무 비싸서 군포가 더 비싸고 의정부가 제일 싼데 광주는']
# 뮤지컬 '여신님이 보고 계셔'가 인천은 너무 비싸고 군포가 더 가깝고 저렴하여 같이 보러 갈 사람을 찾는다.
#
# ['술을 많이 먹고 숙취가 심해서 집에 가려다가 다시 기숙사로 돌아왔다.', '술을 너무 많이 먹고 숙취가 심해서 집에 가려고 다시 기숙사로 돌아왔다.', '술을 많이 먹고 숙취가 심해서 집에 가려다가 다시 기숙사로 돌아왔다.']
# 술을 많이 먹었더니 숙취가 심해서 집 대신 기숙사(긱사)로 돌아왔다.
#
# ['15분 20분 늦을 것 같아서 버스를 탔다.', '15분 20분 늦을 것 같아서 버스를 탔다고 한다.', '15분 20분 늦을 것 같아서 버스를 탔다.']
# 좀 늦을 것 같은데 지금 버스 탔다며 안 막히면 금방 갈 수 있다고 한다.
#
# ['버스 탈 때 출발하면 될 것 같고 버스를 탈 때 연락 달라고 한다.', '버스 탈 때 출발하면 될 것 같고 버스가 몇 분 걸리니 버스 탈', '버스 탈 때 출발하면 될 것 같고 버스가 몇 분 걸리니 버스를']
# 버스 탈 때 출발할 테니 버스 탈 때 연락을 달라고 하고 있다.
#
# ['월곶도 밤까지 화려한 동네라서 밤에도 먹을 건 많은데 구디 쪽에서', '월곶도 밤까지 화려한 동네라서 밤에도 먹을 건 많은데 구디 쪽', '월곶도 밤까지 화려한 동네라서 밤에도 먹을 건 많은데 구디에서']
# 장을 보고 곱창을 먹으러 가자고 한다.
#
# ['내일 치즈메이커를 직거래를 하게 되었는데 같이 가줄 수 있는지 물어', '내일 치즈메이커를 직거래를 하게 되었는데 같이 가줄 수 있냐고', '내일 치즈메이커를 직거래를 하게 되었는데 같이 가줄 수 있는지 묻고']
# 동생이 오빠에게 치즈 메이커 직거래에 같이 가달라고 말하자 두 사람이 만날 시간을 조율하고 있다.
#
# ['다 같이 딸기 뷔페를 가려고 했는데 예약 마감이라 3월 말에 시간이 된다고', '다 같이 딸기 뷔페에 가려고 했는데 예약 마감이라서 대기 중이다.', '다 같이 딸기 뷔페를 가려고 했는데 예약 마감이라 3월 말에 시간 된다고']
# 딸기 뷔페에 가려고 했는데 예약 마감이라 대기가 되어 있고, 다른 친구의 스케줄에 맞춰 3월 말에 갈 수도 있다고 대화하고 있다.
#
# ['남대문 근처에서 기다리고 있고 이따가 회현역에 도착할 예정이다.', '남대문 근처에서 기다리고 있고 이따가 회현역에 도착할 것 같다고 한다.', '남대문 근처에서 기다리고 있고 이따가 회현역에 도착할 것 같다.']
# 한 사람은 사당에서 회현역에 도착했고 다른 사람은 남대문 근처에서 기다리고 있다.
#
# ['올 때 카누를 타 먹으라고 했는데 너무 오랜만이라 얼음을 안 챙겨', '올 때 카누를 타 먹으라고 했는데 너무 오랜만이라 얼음을 안 챙', '올 때 카누를 타 먹으라고 하며 올 때 얼음을 사 오라고 하고']
# 커피를 마실 꺼면 얼음을 사 오라 해서 얼음을 샀고 상대방은 메가에서 큐브 라테를 사 먹었다.
#
# ['늦어도 6시가 될 것 같다고 하자 나는 지금 6시가 예상된다며 미안하다고', '늦어도 6시가 될 것 같다고 하자 자기는 지금 6시가 될 것 같다고', '늦어도 6시가 될 것 같다고 하자 나는 지금 6시가 될 것 같다고 한다.']
# 지금 6시로 예상한다며, 아빠한테 미안하다고 말해달라고 한다.
#
# ['수성못, 팬아시아 범어동 슬로우라이프 수성못 러브호텔이 맛있', '수성못, 팬아시아 범어동 슬로우 라이프 수성못 러브호텔이 맛있', '수성못, 팬아시아 범어동 슬로우 라이프 수성못 러브 호텔을 가']
# 언니랑 내일 어디로 갈지 정하고 있다.
#
# ['집에 간다고 해서 홍콩 반점 앞이라고 했더니 거짓말하지 말라고 한다.', '집에 간다고 해서 홍콩 반점 앞이라고 하니 거짓말하지 말라고 한다.', '집에 간다고 해서 홍콩 반점 앞이라고 하니 거짓말하지 말라고 한다.']
# 홍콩 반점 앞이라고 하는데 없는데 거짓말하지 말라고 간다고 하니 투썸플레이스 앞이라고 한다.
#
# ['부산에 자대배치를 받고 처음 보는 거라 11시 반에 출발할 것 같', '부산에 자대배치를 받고 처음 보는 거라서 늦을 것 같다고 하자', '부산에 자대배치를 받고 처음 보는 거라서 늦을 것 같다고 해서']
# 비가 오지만 어떤 사람이 자대 배치받은 후 처음 보는 날이라 늦을 것 같았고 볶음밥을 먹고 집에 가고 있다.
#
# ['오늘은 맛있는 거 먹는 날이라서 과외 끝나고 20분까지 가기로 한다.', '오늘은 맛있는 거 먹는 날이라서 과외 끝나고 20분까지 가기로 했다.', '오늘은 맛있는 거 먹는 날이라서 과외 끝나고 20분까지 간다고 한다.']
# 오늘 맛있는 것을 먹자고 하며 5시 15분이나 20분까지 만나기로 한다.
#
# ['운동 끝나고 10:20에 만나기로 한다.', '운동 끝나고 10:20에 만나기로 한다.', '운동 끝나고 10:20에 만나기로 한다.']
# 카페에 가면 더 늦어진다고 하니 운동을 10시 20분에 끝내서 같이 걸어오자고 한다.
#
# ['내일 쿠차라 가려고 했는데 생리 때문에 못 갈 것 같다.', '내일 쿠차라 가려고 했는데 너무 당겨서 어디 못 갈 것 같다고 한다.', '내일 쿠차라 가려고 했는데 생리를 해서 못 갈 것 같다.']
# 생리하는 사람이 거의 시체라서 내일 어디 못 갈 것 같다.
#
# ['내일 만나서 숙소를 같은 곳으로 할 거냐고 물어보기로 했다.', '내일 만나서 숙소를 같은 곳으로 할 거냐고 물어보려고 한다.', '내일 만나서 숙소를 같은 곳으로 할지 물어보기로 했다.']
# 숙소를 같은 곳으로 할 것인지 내일 물어봐야겠다는 것과 숙소비를 얼마로 생각하는지에 대해 대화한다.
#
# ['7월에 여수 낭만 포차거리 같은 곳에 가기로 했다.', '7월에 여수 낭만 포차거리 같은 곳에 가기로 했다.', '7월에 여수 낭만 포차거리 같은 곳에 가기로 했다.']
# 오징어 철이 되면 열리는 곳이고 운송시간이 지체되면 신선도가 떨어져서 한 근처에서 싸게 파는 것이라 가고 싶다고 한다.
#
# ['울산에 가고 싶은데 집에 일이 있어서 안 된다고 한다.', '울산에 가고 싶은데 집에 일이 있어서 안된다고 하자 하루 종일 바다 보러 가고 싶다고', '울산에 가고 싶은데 집에 일이 있어서 안 된다고 한다.']
# 울산에 가겠냐고 하자 가고 싶은데 오늘 집에 일이 있어서 안 된다고 하자 혼자 가겠다는 말에 아쉽다고 하면서 가족 상황을 설명한다.
#
# ['어센트 호텔은 방 두 개에 세금을 다 해서 21만 원이고 여기는 방 한', '어센트 호텔은 방 두 개에 세금을 다 해서 21만 원이고 여기는 방 두', '방 두 개에 세금을 다해서 22만 원인데 방은 이따가 결정하기로']
# 호텔방 2개를 예약하기로 결정하고 가격과 위치를 비교한다.
#
# ['캠핑카를 빌려서 여행을 다녀버렸다고 하니 캠핑카는 별로라고 한다.', '캠핑카를 빌려서 여행을 다녀버렸다고 하니 캠핑카는 별로라고 한다.', '캠핑카를 빌려서 여행을 다녀버렸다고 하니 캠핑카가 별로라고 한다.']
# 여행을 다닐 때 캠핑카가 좋은지 펜션이나 에어비앤비가 좋은지에 대해 토론한다.
#
# ['도착하면 마트에서 맛있는 것을 사기로 하고 이제 터미널이다.', '도착하면 마트에서 맛있는 것을 사기로 하고 이제 터미널에 간다.', '도착하면 마트에서 맛있는 것을 사기로 하고 터미널에 3분 뒤에 나간다고 한다.']
# 라면과 함께 먹을 다른 것을 사기 위해 만나서 마트에 가기로 한다.
#
# ['집에서 혼자 염색 중인데 45분에 머리를 감아야 해서 45분에 머리를 감아야 한다.', '집에서 혼자 염색 중인데 45분에 머리를 감아야 해서 45분에 머리를 감아야 해서', '집에서 혼자 염색 중인데 45분에 머리를 감아야 해서 45분에 머리 감아야 한다.']
# 염색 중이라 45분에 머리 감아야 돼서 좀 걸린다고 했다.
#
# ['100메가 바이트가 남았는데 라면이랑 같이 먹자고 하니 아르바이트', '100메가바이트가 남았는데 라면이랑 같이 먹자고 하니 아르바이트', '100메가바이트가 남았는데 라면이랑 뭐랑 같이 먹을지 고민']
# 언니가 음식을 사 와서 같이 먹자고 했으나, 동생은 아르바이트(알바)가 4시 반에 끝나니 먼저 먹고 있으라고 한다.
#
# ['주말에 먹고 스터디 카페에 가자고 하니 주말에는 공부할 이유가 없다고 한다.', '주말에 먹고 스터디 카페에 가자고 하자 주말에는 공부할 이유가 없다고 한다.', '주말에 먹고 스터디 카페에 가자고 하니 주말엔 공부할 이유가 없다고 한다.']
# 주말에 스터디 카페에 가자고 하니 금요일에 시험이 끝나서 주말에 공부할 필요가 없고 주말에는 알바라고 한다.
#
# ['추석이라 신난다고 하고 다니면 사장님들이 결혼을 안 해서 그런 건데 자기들은', '추석이라 신난다고 하고 다니면 사장님들이 결혼을 안 해서 그런데 아직 안', '추석이라 신난다고 하고 다니면 사장님들이 결혼을 안 해서 안 좋다고 물어보는']
# 추석이라서 좋다고 하니까, 결혼을 안 해서 그런 거라고 하면서 철없다는 소리도 들었다.
#
# ['어린이대공원에서 3시에 만나서 간식사 들고 가서 점심을 먹기로 했다.', '어린이대공원에서 3시에 만나서 간식사 들고 가서 점심을 먹기로 한다.', '어린이대공원에서 3시에 만나서 간식사 들고 가서 점심을 먹자고 한다.']
# 점심을 먹고 세시에 어린이대공원에 가기로 했다.
#
# ['지금은 좀 나아졌지만 지금은 사람이 너무 많다고 해서 그냥 물류 오면 간다고 했다.', '지금은 좀 나아졌지만 지금은 사람이 너무 많다고 해서 그냥 물류 오면 간다고 한다.', '지금은 좀 나아졌지만 지금은 사람이 너무 많다고 해서 그냥 물류 오면 가기로 했다.']
# 사람 너무 많다고 하니 지금도 많냐고 묻고 지금은 좀 나아졌다고 하니 12시 40~50분쯤 간다고 한다.
#
# ['언니가 수영장에서 노는 사진을 보내줘서 7박 9일로 여행을 다녀왔다.', '언니가 수영장에서 노는 사진을 보내줘서 7박 9일로 여행을 갔다고 한다.', '언니가 수영장에서 노는 사진을 보내줘서 7박 9일로 여행을 가셨다.']
# 언니 여행 갔냐고 하니 어제 7박 9일로 갔다며 수영장에서 노는 사진을 보여주고 있다.
#
# ['엄마가 찾아준 필리핀 현지식당에서 한국밥을 먹기로 한다.', '엄마가 찾아준 필리핀 현지식당에서 한국밥을 먹기로 했다.', '엄마가 찾아준 필리핀 현지식당에서 한국 밥을 챙겨가기로 한다.']
# 필리핀 현지식보다는 한국에서 밥 될 것을 챙겨 가는 것이 나을 것 같다.
#
# ['이태원에 도착해서 녹사평역에서 택시를 타고 가까운 술집에 가려고 한다.', '이태원에 도착해서 녹사평역에서 택시를 타고 가까운 술집에 가기로 했다.', '이태원에 도착해서 녹사평역에서 택시를 타고 가까운 술집으로 가려고 한다.']
# 이태원에서 택시를 타고 녹사평역까지 가야 해서 먼저 가까운 술집에 들어가라고 제안하고 있다.
#
# ['가족에게 민폐일 수도 있으니 밖에서 밥을 먹으라고 한다.', '가족들한테 민폐일 수 있어서 밖에서 밥을 먹으려고 한다.', '가족들한테 민폐일 수 있어서 밖에서 밥을 먹으려고 한다.']
# 다같이 집에서 조금만 쉬다가 새벽 스키를 타러 가기로 한다.
#
# ['아빠가 3시에 회사 끝난다고 밭에 가서 고와달라고 해서 내일 같이 보기로', '아빠가 3시에 회사 끝난다고 밭에 가서 고와달라고 해서 내일 같이 보자고', '아빠가 3시에 회사 끝난다고 밭에 가서 양화 예매를 해달라고 해서 못']
# 아빠가 3시에 밭에서 도와달라고 하여 오늘은 못 갈 거 같아 사과한다.
#
# ['언니가 애들을 데리러 나가려고 5시쯤 나간다고 한다.', '언니가 애들을 데리러 나가려고 5시쯤 나갈 예정이다.', '언니가 애들을 데리러 나가려고 5시쯤 나가려고 한다.']
# 5시쯤 나갈 것 같은데 나갈 때 연락을 달라고 했다.
#
# ['강릉은 여행지로 딱이고 바다도 있고 크피도 맛있다고 해서 가고 싶어졌다.', '강릉에 여행지로 딱이고 바다도 있고 크피도 맛있다고 해서 가고 싶어졌다.', '강릉은 여행지로 딱이고 바다도 있고 크피도 맛있다고 해서 가고 싶어진']
# 강릉의 유명 관광지에 대해 이야기하고 있다.
#
# ['대만 지우펀거리에 있는 숙소에 대해 이야기하고 있다.', '대만 지우펀거리에서 온천도 있고 애니메이션 센과 치히로에서 나온', '대만 지우펀거리에서 온천도 있고 애니메이션 센과 치히로가 나온다.']
# 대만에 가볼지 의견을 묻고 갈 만한 곳에 대해 이야기를 나눈다.
#
# ['11시 20분쯤 오실 것 같고 카페에서 보기로 했으면 1시간 만나면 된다.', '11시 20분쯤 오실 것 같은데 점심 좀 늦어진다고 상황 봐서 알려준다고', '11시 20분쯤 오실 것 같은데 점심 좀 늦어진다고 상황 봐서 알려주겠다고']
# 갑자기 약속을 잡아서 11시 20분쯤 오시는데 남편 혼자 밥 먹어도 괜찮냐고 하니까 상관없다고 한다.
#
# ['지금 방인데 지금 간다고 한다.', '방에 갔냐고 물으니 지금 간다고 한다.', '지금 방인데 지금 간다고 한다.']
# 뭘 하고 있는지 묻고 방으로 지금 간다고 한다.
#
# ['축협에서 소독제랑 살균 화장지를 사서 같이 들어오기로 했다.', '축협에서 소독제랑 살균 화장지를 사러 가기로 했다.', '축협에서 소독제랑 살균 화장지를 사러 가기로 했다.']
# 쓰레기봉투랑 필요한 거 축협에서 살까 물으니 이따 축협에서 만나자고 한다.
#
# ['언니가 다이소에서 산 마우스가 고장 나서 유에스비(usb) 인식을', '언니가 다이소에서 산 마우스가 고장 나서 유에스비(usb)를 인식', '언니가 다이소에서 산 마우스가 고장 나서 유에스비(USB)를 인식']
# 만나기 위해 준비를 하고 무선 마우스를 가져달라고 부탁하며 도착한 장소를 공유한다.
#
# ['더풀버거와 더풀, 헐스벤드를 먹으러 가기로 했다.', '더풀버거와 더풀, 헐스벤드를 먹으러 가기로 한다.', '더풀버거와 더풀, 헐스벤드를 먹으러 가기로 하고']
# 여행 첫날에 갈 곳들의 순서를 정했고 집에 가서 더 추가를 할 것이다.
#
# ['토요일(토욜)에 서면에서 스파이디 핫트랙스를 보기로 했다.', '토요일(토욜)에 서면에서 스파이디 핫트랙스를 보자고 한다.', '토요일(토욜)에 서면에서 스파이디 핫트랙스를 보기로 했다.']
# 토요일에 서면에서 만나면 상대방이 너무 멀기 때문에 미안해했다.
#
# ['11월에 떡볶이를 같이 먹어주기로 했다.', '11월에 떡볶이를 같이 먹어주기로 했다.', '11월에 떡볶이를 같이 먹어주기로 하고 내일 오라고 한다.']
# 11월에 떡볶이를 같이 먹을 것에 대해 이야기하고 있다.
#
# ['집 앞으로 통근차가 있는지 보겠다고 하자 우리 집 쪽으로 오는 게 거의 없을 거라고 한다.', '집 앞으로 통근차가 있는지 보겠다고 하자 우리 집 쪽으로 오는 게 거의 없다고 한다.', '집 앞으로 통근차가 있는지 보겠다고 하자 우리 집 쪽은 오는 게 거의 없다고 한다.']
# 상대방의 집 앞으로 가는 통근차가 있는지 찾아보고 있다.
#
# ['일반 멤버는 두 달에 1회 필참이고 운영진은 월 1회 필참인데 운영진이', '일반 멤버는 두 달에 1회 필참이고 운영진은 월 1회 필참이고 시즌', '일반 멤버는 두 달에 1회 필참이고 운영진은 월 1회 필참인데 운영']
# 참석해야 하는 모임의 회원별 필 참 요건에 대해서 대화한다.
#
# ['금요일(금욜)에 4~5시 정도에 마쳐서 1시쯤 출발하면 된다.', '금요일(금욜)에 4~5시 정도에 마쳐서 1시쯤 출발하면 된다고', '금요일(금욜)에 4~5시 정도에 마쳐서 시차를 쓰고 1시쯤']
# 금요일에 언제 올지에 대해서 이야기하다가 1시쯤 출발해서 일찍 만나기로 결정했다.
#
# ['다음 주(담주)에 쉴 때 부산에 가면 안 될 것 같고 전라도', '다음 주에 쉴 때 부산에 가면 안 되니까 여수를 가려고 한다.', '다음 주에 쉴 때 부산에 가면 안 되니까 여수를 가자고 한다.']
# 다음 주 쉬는 날 부산에 가면 안 되고 가려면 여수를 가야 한다.
#
# ['호텔에 올라가서 여권을 챙겨서 돈키호테까지 걸어서 갔다 오', '호텔에 올라가서 여권을 챙겨서 돈키호테까지 걸어서 갔다 온', '호텔에 올라가서 여권을 챙겨서 돈키호테까지 걸어서 갔다 올']
# 돈키호테까지 1.1킬로라며 호텔에서 여권 챙겨서 걸어서 갔다 오겠다고 하자 13분 거리라 가깝지 않은데 걸어가냐고 한다.
#
# ['목요일에 할아버지(할모) 생일이어서 금요일(금)에 만나', '목요일에 할머니(할모니) 생신이라 금요일에 만나기로 했다.', '목요일에 할아버지(할모) 생일이어서 금요일에 만나기로 했다.']
# 할머니 생신이라서 일단 금요일에 보기로 결정했다.
#
# ['수성못에서 2시까지 만나서 맛있는 거 많이 먹고 오라고 하였다.', '수성못에서 2시까지 만나서 맛있는 거 많이 먹고 오라고 한다.', '수성못에서 2시까지 만나서 맛있는 거 많이 먹고 오라고 한다.']
# 2시까지 수성못에서 만나기로 한 사람들에게 맛있는 걸 많이 먹고 오라고 말하고 있다.
#
# ['베트남 비행기를 놓친 이후로 비행기 편명을 제대로 입력하지 못해서 이번에 꼭 제', '베트남 비행기를 놓친 이후로 비행기 편명을 제대로 입력하지 못해서 못 믿겠', '베트남 비행기를 놓친 이후로 비행기 편명을 제대로 입력하지 못해서 이번에 꼭 돌아와']
# 비행기 편명을 제대로 입력했는지 스스로 확신이 없어서 상대방에게 재확인해달라고 부탁했다.
#
# ['표를 나눠줄 수 있는 게 아니라 표를 나눠줄 수 있는 게 아니라 급행 지하철을', '급행 지하철을 탔는데 표를 나눠줄 수 있는 게 아니어서 표를 나눠줄 수', '표를 나눠줄 수 있는 게 아니라 표를 나눠줄 수 있는 게 아니라 급행 열차를']
# 알람이 울리지 않아 급행을 타고 가야 할 것이고 광고 끝나기 전에 도착할 것이다.
#
# ['7/11이 시험(셤) 보는 날이라 미뤄야 될 것 같다고 해서', '7/11이 시험(셤) 보는 날이라 미뤄야 할 것 같다고 해서', '7/11이 시험(셤) 보는 날이라서 미뤄야 할 것 같다고']
# 7월 11일에 지인을 만나기로 했는데 시험 보는 날이라서 미룬 상황에 대해 이야기한다.
#
# ['더 나은 곳이 없으면 얘기 나온 곳 중에 골라보기로 하고 언니가 마음에 들면 근처 맛', '언니가 마음에 들면 근처 맛집을 찾아보기로 했다.', '더 나은 곳이 없으면 얘기 나온 곳 중에 골라보기로 했다.']
# 맛집을 정해야 하는데 더 나은 곳이 없으면 얘기 나온 곳 중에 고르자고 이야기한다.
#
# ['잠실타워는 아직 안 가봤고 양재천도 나중에 가자고 한다.', '잠실타워는 아직 안 가봤고 양재천도 나중에 가기로 했다.', '잠실타워는 아직 안 가봤고 양재천도 나중에 가기로 한다.']
# 동생이 잠실타워와 양재천을 안 가봐서 나중에 가기로 한다.
#
# ['런던행 비행기 표가 가격이 많이 올랐는데 저번에 예매했어야 했나', '런던행 비행기 표가 가격이 많이 올랐는데 저번에 예매했어야 했다고 한다.', '지금 런던행 비행기 표가 너무 비싸서 더 기다려보자고 한다.']
# 런던행 비행기(뱅기) 표 가격이 갑자기 많이 올랐는데 다시 떨어질 것 같으니 기다려 보자고 한다.
#
# ['제주도에 가면 셔틀버스를 타고 체험 같은 것도 하고 숙박은 풀빌라', '제주도에 갈 거면 셔틀버스를 타고 체험도 하고 숙박은 풀빌', '제주도에 가면 셔틀버스를 타거나 체험 같은 것도 하고 숙박은 풀빌']
# 제주도에 가면 셔틀버스, 체험 등의 경험을 하고, 저렴하기 때문에 풀빌라와 같은 좋은 숙박시설에서 묵어야 한다.
#
# ['당일치기로 맛있는 거 먹고 오거나 계곡에 가서 발 담그다가 백숙을', '당일치기로 맛있는 거 먹고 오거나 계곡에 가서 발 담그다가 백숙 먹고', '당일치기로 맛있는 거 먹고 오거나 계곡에 가서 발 담그고 백숙을']
# 당일치기로 가까운 계곡에 가서 발 담그고 백숙 먹고 저녁에 오자고 엄마와 휴가 계획에 대해 대화한다.
#
# ['4월 6일 날 시험이라 서울에 갈 수 없고 창원에 갈 것이다.', '4월 6일 날 시험이라 서울에 갈 수 없어서 창원에 가기로 한다.', '4월 6일 날 시험이라 서울에 갈 수 없어서 창원에 가기로 한다.']
# 시험 때문에 서울에 갈수 없어서 창원에서 만나기로 한다.
#
# ['양 꼬치를 먹고 호텔에 갔다고 하자 재밌게 놀고 술은 적당히 마시', '양 꼬치를 먹고 호텔에 가서 술을 마시고 있다.', '양 꼬치를 먹고 호텔에 갔다고 하자 재밌게 놀고 술은 적당히 먹']
# 양꼬치를 먹고 호텔로 가고 있다고 하자 재미있게 놀고 술은 적당히 마시라고 한다.
#
# ['화엄사는 멀고 기대도 안 해서 안 가도 될 것 같다.', '화엄사는 멀고 기대도 안 해서 안 가도 된다.', '화엄사는 멀고 기대도 안 해서 안 가도 되지만 어차피 기대도 안']
# 화엄사에 가기로 한 약속은 깨진 건지 묻자 너무 멀고 귀찮다고 하면서 가지 않기로 한다.
#
# ['지인이 준 폴바셋이 있어서 산책을 가기로 했다.', '지인이 준 폴 바셋이 있어서 산책을 가기로 한다.', '지인이 준 폴바셋이 있어서 산책을 가기로 했다.']
# 누가 준 폴바셋 쿠폰이 있어서 폴바셋에 간다.
#
# ['내일 몇 시에 볼지 물어보고 알려주겠다고 한다.', '내일 몇 시에 볼지 물어보고 알려주기로 했다.', '내일 몇 시에 볼지 물어보고 알려주기로 했다.']
# 토요일에 어디로 갈지 물어봐 주겠다고 이야기한다.
#
# ['어제 왔는데 안 돌아다녀서 내일 어디 갈지 모르겠다.', '어제 왔는데 안 돌아다녀서 내일 어디 갈지 모르니 일단 너네 집으로', '어제 왔는데 안 돌아다녀서 내일 어디 갈지 모르겠으니 일단 너네 집으로']
# 내일 집으로 간다고 말했다.
#
# ['이번 주에 양양에 서핑을 하러 가는데 누구 친구가 거기 간다고', '이번 주에 양양에 서핑을 하러 가는데 누구 친구는 거기 간', '이번 주에 양양에 서핑을 하러 가는데 누구 친구가 양양에']
# 이번 주에 양양으로 서핑을 타러 간다는 이야기를 하고 있다.
#
# ['언니가 맥주를 전혀 안 마셔서 맥주 한 잔만 한다.', '언니가 맥주를 전혀 안 마셔서 맥주 한 잔만 한다고 하자 나는 와인이나', '언니가 맥주를 전혀 안 마셔서 맥주 한 잔만 한다고 하자 자신은 와인이나']
# 언니가 술을 안 마시기도 했고 자신도 배가 불러서 술을 안 먹었다는 이야기를 한다.
#
# ['부모님이 화요일에 쉬고 수요일에 쉰다고 해서 목요일에 시키기로', '부모님이 화요일에 쉬고 수요일에 쉰다고 해서 목요일에 시킨', '부모님이 쉰다고 해서 화, 수, 목요일에 쉰다고 해서 목']
# 엄마랑 아빠(엄빠)는 금요일(금욜)에 쉬고 화수목에 나간다.
#
# ['씻고 가기에는 너무 늦어서 안 올 것 같다고 하자 우리가 빠져준 거라고 한다.', '씻고 가기엔 너무 늦어서 안 올 거 같다고 하자 지금 온다고 한다.', '씻고 가기엔 너무 늦어서 안 올 거 같다고 하자 지금 온다고 한다.']
# 안 올 것 같다고 생각했던 다른 사람이 일찍 끝나서 지금 온다고 한다.
#
# ['다음 주에 만나서 기흥까지 같이 가면 될 것 같다.', '다음 주에 만나서 기흥까지 같이 가기로 했다.', '다음 주에 만나서 기흥까지 같이 가면 될 것 같다.']
# 다음 주에 10시 전에 기흥까지 같이 가기로 했다.
#
# ['회식이 월요일이어서 화요일로 바꿀 수 있겠다고 한다.', '회식이 월요일이어서 화요일로 바꿀 수 있겠다고 한다.', '회식이 월요일이어서 화요일로 바꿀 수 있을 것 같다고 한다.']
# 회식이 월요일(월욜)이라서 날짜를 화요일(화용, 화욜)로 바꾸려고 했는데 애매하다고 한다.
#
# ['기내 캐리어 센티를 맞춰서 샀는데 괜찮은지 물어본다.', '기내 캐리어 센티를 맞춰서 샀는데 괜찮은지 물어보고 있다.', '기내 캐리어를 센티미터(센치)에 맞춰 샀는지 물어보고 있다.']
# 크기를 맞춰 기내 캐리어를 사지 않았지만 티웨이는 재보지 않으니 괜찮을 거라고 말하고 있다.
#
# ['저녁에 친구들을 만나기로 했는데 시간이 애매해서 일찍 헤어졌다.', '저녁에 친구들을 만나기로 했는데 시간이 애매해서 일찍 헤어졌다.', '저녁에 친구들을 만나기로 했는데 시간이 애매해서 일찍 헤어졌다.']
# 신발 환불하러 강남역에 가는 김에 약속을 잡고 했지만 선약이 있어 다음에 보기로 했다.
#
# ['애슐리에 가고 싶으면 주말에 가자고 한다.', '주말에 애슐리에 가서 모든 메뉴를 먹어보고 싶다.', '애슐리에 가고 싶으면 주말에 가자고 한다.']
# 주말에 애슐리에 가서 모든 메뉴를 먹어 보고 싶다.
#
# ['일주일간 여행을 허락받았는데 갈 사람이 없다.', '일주일간 여행을 허락받았는데 갈 사람이 없다.', '일주일간 여행을 허락받았는데 갈 사람이 없다고 한다.']
# 일주일간 여행을 허락받았는데 혼자 여행은 안 된다.
#
# ['다음 주 금요일에 영일대에서 피크닉을 하러 가기로 했다.', '다음 주 금요일에 피크닉을 가자고 제안하고 있다.', '다음 주 금요일에 영일대에서 피크닉을 하자고 제안하고 있다.']
# 다음 주에 날씨 좋을 때 피크닉을 가자는 대화를 한다.
#
# ['6시에 끝날 것 같으니 천천히 오라고 한다.', '6시에 끝날 것 같으니 천천히 오라고 한다.', '6시에 끝날 것 같으니 천천히 오라고 한다.']
# 6시에 끝날 것 같다고 하자, 천천히 오라고 한다.
#
# ['오늘 홈플러스(홈플러스)에 들렀다 간다고 한다.', '오늘 홈플러스(홈플러스)에 들렀다 가겠다고 한다.', '오늘 홈플러스(홈플러스)에 들렀다 간다고 했다.']
# 애들을 만났는데 먹을 것을 사기 위해 홈플러스를 들렀다 간다고 한다.
#
# ['장례는 내일 오후 반차를 쓰고 오후에 하고 오늘은 아이스팩을 옆에 두고 나왔다.', '장례는 내일 오후 반차를 쓰고 오후에 하고 오늘은 아이스팩을 옆에 두고 나와서', '장례는 내일 오후 반차를 쓰고 오후에 하고 오늘은 아이스팩을 옆에 두고 나왔다고']
# 내일 오후에 반차 쓰고 장례를 하려고 한다.
#
# ['오늘 친구들과 한강에서 만나기로 했다.', '친구들이랑 한강에서 보기로 해서 돗자리를 깔지 않고 계단에 앉는다.', '오늘 친구들과 한강에서 만나기로 했다.']
# 친구들과 한강에서 만나기로 했고 돗자리는 안 깐다고 한다.
#
# ['방콕을 한 번 밖에 안 갔는데 이제 다시 간다고 한다.', '방콕을 한 번 밖에 안 갔는데 이제 다시 간다고 한다.', '방콕을 한 번밖에 안 갔는데 한 번밖에 안 갔다고 한다.']
# 여러 번 간 것 같지만 둘이 같이 갔을 때가 마지막이었던 방콕을 드디어 다시 가는 것에 대해 이야기한다.
#
# ['목요일 3시 30분에 번개 모임이 있는데 평소라면 갔겠지만 컴퓨터 활용 능력(', '목요일 3시 30분에 만나기로 하고 평소라면 갔겠지만 컴퓨터 활용(컴활)', '목요일 3시 30분에 번개 모임이 있는데 평소라면 갔겠지만 컴퓨터 활용(컴']
# 평소라면 번개 모임도 좋지만 오늘은 컴퓨터 활동 능력(컴활) 공부를 해야 해서 목요일 3시 30분에 보기로 한다.
#
# ['애들이 너무 많아서 치킨도 너무 많고 치킨도 너무 많아서 6시에 들어간다고', '애들이 너무 많아서 치킨도 너무 많고 치킨도 너무 많아서 6시에 들어갈 것이다.', '애들이 너무 많아서 치킨도 너무 많고 치킨도 너무 많아서 6시에 들어가겠다고']
# 배고프다고 해서, 야구로 꼬셔보라고 했더니, 야구로도 안 들어간다고 해서, 치킨을 갖다주려고 했지만 애들이 많아서 6시에 들어간다고 한다.
#
# ['지금 에어아시아가 방콕 왕복이 20만 원이라서 같이 가고 싶다고 한다.', '지금 에어아시아가 방콕 왕복이 20만 원이라서 같이 가고 싶은데 기간이', '지금 에어아시아가 방콕 왕복이 20만 원이라서 가고 싶다.']
# 에어아시아로 방콕이 왕복 20만 원이라며 엄청 싸다며 가고 싶다고 하고 있다.
#
# ['9월 중순이나 그다음 주에 가격이 별로 안 비쌀 것 같다고 이야기하고 있다.', '9월 중순이나 그다음 주에 가격이 별로 안 비쌀 것 같다고 한다.', '9월 중순이나 그다음 주에 가격이 별로 안 비쌀 것 같다.']
# 9월 중순에 수영장이 있는 곳은 가격이 비싸지만 가자고 한다.
#
# ['엄마에게 어디 갈지 찾았다며 제부도를 갈 거라고 하자 일요일에 갔다가', '엄마에게 어디 갈지 찾았다고 하니 제부도를 갈 거라고 하고 일요일에 갔다가', '엄마에게 어디 갈지 찾았다며 제부도를 갈 거라고 하자 일요일에 당일치']
# 제부도를 간다고 하고 일요일에 갔다가 월요일에 오는 것에 대해 이야기한다.
#
# ['춘천은 갈비를 재워갈 것이고 큰집은 이번 추석만 고기를 보내려고', '춘천은 갈비를 재워갈 거고 큰집은 이번 추석만 고기를 보내', '춘천은 갈비를 재워갈 거고 큰집은 이번 추석만 고기를 보낼']
# 춘천에는 갈비 재워가고 큰집은 지나가려 한다.
#
# ['생리대 주머니에 130불 더 있어서 숙소 값을 따로 빼놨다.', '생리대 주머니에 130불 더 있어서 숙소 값을 따로 빼놨다고 한다.', '생리대 주머니에 130불 더 있어서 숙소값 따로 빼놨었다고 한다.']
# 생리대 주머니에 숙소비 130불 더 있어서 돈을 안 뽑아도 되겠다고 했다.
#
# ['열한시 반까지 수다 떨다가 나가서 점심거리 반찬이라도 사야', '열한시 반까지 수다를 떨다가 나가서 점심거리 반찬 같은 거', '열한 시 반까지 수다 떨다가 나가서 점심거리 반찬이라도 사야']
# 열한 시 반까지 수다 떨다가 나가서 점심거리를 사야겠다고 말하고 있다.
#
# ['8번 출구로 나오라고 해서 5분 안에 간다고 한다.', '8번 출구로 나오라고 해서 5분 안에 간다고 한다.', '8번 출구로 나오라고 해서 5분 안에 간다고 한다.']
# 자신의 이동 동선을 알려주며 약속 장소까지 가고 있다.
#
# ['장인어른 생신이라 지금 집에 가는데 차가 막히면 늦게 간다.', '장인어른 생신이라 집 갔는데 차가 막히면 지가 늦게 간', '장인어른 생신이라 지금 집에 가는데 차가 막히면 늦게 가는 거라고']
# 장인어른 생신이라 집 가는데 자기도 엄마 생일마다 집 가려 하고 금요일이라 참는다.
#
# ['아직 구체적이진 않지만 오빠와 많은 것들을 같이 하고 싶다고 한다.', '아직 구체적이진 않지만 오빠와 많은 것들을 같이 하고 싶다고 한다.', '아직 구체적이진 않지만 오빠와 많은 것들을 같이 하고 싶다고 한다.']
# 오빠가 어떤 걸 같이 하고 싶어 하는지 구체적으로 궁금하다.
#
# ['강창교에 있는 대구은행 에이티엠(atm)에서 바나나 원', '강창교에 있는 대구은행 에이티엠(atm)에서 만나기로 했다.', '강창교에 있는 대구은행 에이티엠(atm)에서 바나나 원을']
# 물과 바나나를 챙겨서 집 앞 대구은행 에이티엠(atm)으로 나오라고 한다.
#
# ['제주도 마당 여관이라는 숙소가 어떤지 물어보고 있다.', '제주도 마당 여관이라는 숙소가 어떤지 물어보고 있다.', '제주도 마당 여관이라는 숙소가 어떤지 물어보고 있다.']
# 제주도 가서 동쪽이 볼거리가 많으니까 동쪽으로 가자고 한다.
#
# ['이번 주 내내 늦는다고 해서 혹시 생기면 알려달라고 했다.', '이번 주 내내 늦는다고 해서 혹시 생기면 말해달라고 한다.', '이번 주 내내 늦는다고 해서 혹시 생기면 말해달라고 한다.']
# 이번 주 내내 늦을 거 같다고 이야기하고 있다.
#
# ['화정역에 있는 피시방에서 12시 반에 만나기로 했다.', '화정역에서 12시 반에 만나서 피시방에 가기로 한다.', '화정역에서 12시 반에 만나서 피시방에 가기로 했다.']
# 12시 반에 화정역에서 만나서 피시방을 가자고 한다.
#
# ['칠순파티가 고깃집이라 차라리 뷔페에 가자고 하자 고기', '칠순파티가 고깃집이라 차라리 뷔페를 가라고 하자 고기', '칠순파티가 고깃집이라 차라리 뷔페에 가자고 하니 고기']
# 칠순 파티를 고깃집에서 하는데 자기들이 고기를 구워야 하니 가기 싫다.
#
# ['타국에 내리지는 않고 외국 하늘만 돌다가 다시 돌아오는 관광이 있다.', '타국에 내리지는 않고 외국 하늘만 돌다가 다시 돌아오는 관광이 있는데 하늘 위에서 섬', '타국에 내리지는 않고 외국 하늘만 돌다가 다시 돌아오는 관광이 있다고 한다.']
# 내리지는 않고 하늘만 돌다가 돌아오는 관광을 설명해 주고 있다.
#
# ['문화관에 언제 갈 거냐고 물으니 이미 거를 고았다며 내려가는 중이라고', '문화관에 언제 갈 거냐고 물으니 이미 거를 고았는데 내려가는 길이라고', '문화관에 언제 갈 거냐고 물으니 이미 거고 내려가는 중이라고 한다.']
# 문화관을 가기 위해 일찍 나왔다.
#
# ['집에 들렀다가 출발하는 시간이 비슷하면 같이 가기로 했다.', '집에 들렀다가 출발하는 시간이 비슷하면 같이 가자고 한다.', '집에 들렀다가 출발하는 시간이 비슷하면 같이 가자고 했다.']
# 집에 들렀다가 가야 해서 바로 갈수 없다고 한다.
#
# ['제주도 식당들 인터넷으로 예약할 수 있는 곳은 산도롱 맨도롱 갈비', '제주도 식당들 인터넷으로 예약할 수 있는 곳은 산도롱맨도롱 갈비', '제주도 식당들 인터넷으로 예약할 수 있는 곳은 산도롱 맨 도롱 갈비']
# 인터넷으로 예약할 수 있는 제주도 식당은 미리 예약하기로 했다.
#
# ['1박을 할지 말지 고민하고 있다.', '1박을 하면 비박을 해야 하고 빌리기도 귀찮고 피곤한데 안', '1박을 하면 비박을 해야 하고 빌리기도 귀찮아서 차를 빌리']
# 여행을 다녀올 기간, 차를 빌릴지 대중교통을 탈지 와 같은 교통 편과 같은 여행 계획을 의논한다.
#
# ['수원 외삼촌이랑 갔던 바다 캠핑장에 금요일에 갔다가 월요일에', '지난번에 수원 외삼촌이랑 갔던 바다 캠핑장에 금요일에 갔다가 월', '수원 외삼촌이랑 갔던 바다 캠핑장에 월요일에 와서 의자와 낚']
# 부모님이 캠핑하는 곳에 먹을 것만 사서 주말에 가자고 한다.
#
# ['내일 베스킨라빈스(베라)에 갔다가 공차에 가기로 했다.', '내일 베스킨라빈스(베라)에 갔다가 공차에 가기로 했다.', '내일 베스킨라빈스(베라)에 갔다가 공차에 가기로 한다.']
# 내일 배스킨라빈스(배라)에 갔다가 오래간만에 공차에 가기로 했다.
#
# ['누나가 일 마무리하면 대전 내려가야겠다고 하자 오늘 저녁 중으로 알려주겠다고 한다.', '누나가 일 마무리하면 대전 내려가야겠다고 해서 오늘 저녁 중으로 알려주기로 했다.', '누나가 일 마무리하면 대전 내려가야겠다며 오늘 저녁 중으로 알려주겠다고 한다.']
# 누나가 일을 마무리하면 대전에 갈 테니 토요일에 꼭 보자고 하니 차 시간을 알려주면 동생도 그 시간대로 차를 알아보기로 했다.
#
# ['집에 있는 케이(K)94 마스크를 꼭 쓰라고 한다.', '집에 있는 케이(K)94 마스크가 있으니 마스크를 꼭 쓰라고 한다.', '집에 있는 케이(K)94 마스크가 있으니 마스크를 꼭 쓰고 오라고']
# 집에 있는 케이에프(KF)94 마스크를 꼭 쓰고 오라고 한다.
#
# ['롯데월드를 가자고 했는데 어제 헤어져서 오늘 롯데월드를 가자고 한다.', '롯데월드를 가자고 했는데 어제 헤어져서 오늘 롯데월드를 간다.', '롯데월드를 가자고 했는데 어제 헤어져서 오늘 롯데월드를 가자고 했다.']
# 어제 사귀던 사람과 헤어져서 오늘 롯데월드에 가자고 연락을 했다.
#
# ['여보는 이 중에 한 곳은 꼭 가야 한다고 골라서 일요일에 가려고 한다.', '여보는 이 중에 한 곳은 꼭 가야 한다고 골라서 일요일에 간다고 한다.', '여보는 이 중에 한 곳은 꼭 가야 한다고 골라서 일요일에 가려고 한다.']
# 일요일에 갈 거니까 여러 군데 중에 하나만 고르라고 한다.
#
# ['다만 악에서 구하소서를 보러 센텀에 가기로 했다.', '다만 악에서 구하소서를 보러 센텀에 가기로 했다.', '다만 악에서 구하소서 영화를 보러 센텀에 가기로 했다.']
# 다만 악에서 구하소서를 보러 센텀시티 시지브이(CGV)에서 보기로 했다.
#
# ['방 탈출 다섯시 사십분 보다 이십분이 낫고 애들이 너무 빨리 끝나서', '방 탈출 다섯시 사십분보다 이십분이 낫고 애들이 너무 빨리 끝나서', '방 탈출이 다섯시 사십분보다 20분이 낫고 애들이 너무 빨리 끝나']
# 애들이 도착하기 전에 방 탈출을 하다 너무 일찍 끝나면 하나를 더 하자고 제안한다.
#
# ['학원 끝나고 저녁을 먹으려고 했는데 너무 피곤해서 못 나가게 되었다.', '학원 끝나고 저녁을 먹으려고 했는데 너무 피곤해서 못 나가게 됐다.', '학원 끝나고 저녁을 먹으려고 했는데 너무 피곤해서 못 나가게 되었다.']
# 피곤해서 저녁 먹으러 못 나가겠다고 하지만 저녁 먹자고 한다.
#
# ['오늘 신데렐라 놀이를 해서 1시까지 들어가기로 했다.', '오늘 신데렐라 놀이를 해서 1시까지 들어가기로 했다.', '오늘 신데렐라 놀이를 해서 1시까지 들어가기로 했다.']
# 수송동에 10시쯤 도착하니 시간 정하지 말고 한 군데서 천천히 마시기로 했다.
#
# ['비가 오는데 일 가는데 짜증 난다고 한다.', '비가 오는데 일 가는데 짜증이 난다.', '비가 오는데 일 가는데 짜증 난다고 한다.']
# 수요일과 목요일에 비가 온다며 하필 일을 갈 때 비가 오냐며 가기 싫다고 하고 있다.
#
# ['회사 밑에 이디야에서 치과 대기를 하고 있다.', '회사 밑에 이디야에서 치과 대기를 하고 있다.', '회사 밑에 이디야에서 치과 대기가 세 시 돼야 끝날 것 같다고 한다.']
# 치과 볼일 끝나고 세 시쯤 회사 아래 이디야에서 커피를 마시기로 했다.
#
# ['전에 계획한 거라 다 끊어놨을 것이고 마일리지를 모으는 중인데', '전에 계획한 거라 다 끊어놨을 거라며 마일리지가 아깝다고', '전에 계획한 거라 다 끊어놨을 거라며 마일리지를 쓰라고 하자']
# 마일리지를 모으는 중이라 쓰기 아깝기도 해서 하루만 고민 좀 하려 한다.
#
# ['웨딩 촬영 날짜를 평일 오후에 잡으려고 한다.', '웨딩 촬영 날짜를 평일 오후로 잡으려고 한다.', '웨딩촬영을 평일 오후로 잡았는데 날짜가 잡히면 알려준다고']
# 웨딩촬영에 오고 싶어 해서 날짜가 잡히면 알려주기로 한다.
#
# ['동생이 안양을 간다고 해서 카페에 가려고 한다.', '동생이 안양을 간다고 해서 카페에 가려고 한다.', '동생이 안양을 간다고 해서 안양으로 갈 때는 오붓하게 함께 오자고 한다.']
# 두 사람이 내일 안양에 따로 갔다가 올 때 만나서 같이 오기로 했다.
#
# ['다른 나라에 여행 갈 때보다 떨린다고 하자 자기도 떨리기보다 떨린다고', '다른 나라에 여행 갈 때보다 떨린다고 하자 자기는 아직 무덤덤하다고 한다.', '다른 나라에 여행 갈 때보다 떨린다고 하자 자기는 아직 무덤덤하다고 한다.']
# 다른 나라 여행 갈 때의 설레는 마음을 안고 수영복을 챙길 건지에 대해 이야기한다.
#
# ['어시장에서 가리비를 사서 삼촌 집에서 솥뚜껑 삼겹살을 구워', '어시장에서 가리비를 사서 삼촌 집에서 솥뚜껑 삼겹살을 해먹', '어시장에서 가리비를 사서 삼촌 집에서 솥뚜껑 삼겹살을 해 먹고']
# 7월에 같이 창원 삼촌 집에 갈 수 있는지 물어보고 안 된다고 하면 부산이나 거제로 가자고 이야기하고 있다.
#
# ['제주도 말고 대만이나 오키나와에 갈까 고민했는데 항공비가 비슷해서 제주도로', '제주도 말고 대만이나 오키나와에 갈까 고민했는데 항공비는 비슷비슷해서', '제주도 말고 대만이나 오키나와에 갈까 고민했지만 항공비가 비슷하니까 제주도로']
# 항공비가 비슷한 제주도로 마음을 결정했다며 일본에서 대만까지는 항공료가 저렴하다고 말하니, 상대방은 대만을 가고 싶다고 한다.
#
# ['킨자돈부리에서 만나기로 하고 부평구청에서 6분 후에 온다고', '킨자돈 부리에서 만나기로 하고 부평구청에서 6분 후에 온다고', '킨자돈부리에서 만나기로 하고 부평구청행 6분 후에 온다고']
# 1시 30분쯤에 신중동 역에 도착할 예정이니 칸지돈부리는 지도를 보고 찾아가겠다고 했다.
#
# ['다섯시 반 퇴근인데 괜찮은지 물어보고 선배님만 되면 그때 보려고 한다.', '다섯시 반 퇴근인데 괜찮은지 물어봤는데 선배님만 되면 그때 보려고', '다섯시 반 퇴근인데 괜찮은지 물어보고 선배님만 되면 그때 보려고 한다고']
# 다섯시 반이 괜찮냐고 묻고 선배님만 되면 다섯시 반에 보자고 한다.
#
# ['11시 50분에 점심을 먹고 회의실에 들어가서 밥을 먹기로 했다.', '11시 50분에 점심을 먹고 회의실에 들어가서 1시까지 들어가면 된다.', '11시 50분에 점심을 먹고 회의실에 들어가서 1시까지 기다리면 된다.']
# 회의실을 잠가야 해서 11시 50분쯤 점심을 먹고 1시까지 들어가야 하는 사람에게 12시까지 나가보겠다고 약속하고 있다.
#
# ['멕시코와 칸쿤은 채식 식단 요금은 가능하지만 국내선은 안된다고 한다.', '멕시코와 칸쿤은 채식 식단 요금은 가능하고 국내선은 안된다고 한다.', '멕시코와 칸쿤은 채식 식단 요금은 가능하지만 국내선은 안된다고 해서']
# 멕시코, 칸쿤행 비행 노선에 따라 지급되는 기내식과 좌석 상황이 다르다고 설명하고 있다.
#
# ['토요일에 약속이 있으면 저녁에 관극을 하기로 했다.', '토요일에 약속이 있으면 저녁에 관극을 하기로 했다.', '토요일에 점심 약속과 저녁에 관극을 하기로 했다.']
# 토요일에 같이 가려고 했는데, 점심 약속과 저녁에 관극이 있다고 이야기한다.
#
# ...
# 여행 후 3시 40분 차를 타고 대구로 돌아갈 것이다.
#
# ['고기도 좋고 신촌도 좋으니 배달을 시켜서 안고 누워있고 싶다.', '고기도 좋고 신촌도 좋으니 배달을 시켜서 안고 누워있고 싶다고', '고기도 좋고 신촌도 좋으니 배달을 시켜서 누워있고 싶다.']
# 종각이면 많이 기다릴 것 같지만 유튜브를 보면 되고 종로 가서 좀 누워있을까 싶다.
#
# ['12시에 끝나냐고 물으니 끈이 나면 연락하겠다고 한다.', '12시에 끝나냐고 물으니 끈이 나면 연락한다고 한다.', '12시에 끝나냐고 물으니 끈이 나면 연락한다고 한다.']
# 끝나면 연락한다고 하니까, 빨리 끝나라고 한다.
#
# ['신반포에서 불꽃놀이를 하는데 사람이 많아서 에스컬레이터를 타고 올라가서', '신반포에서 불꽃놀이를 하는데 사람이 많아서 에스컬레이터를 타고 올라갈', '신반포에서 불꽃놀이를 하는데 사람이 엄청 많을 것 같고 에스컬레이터를']
# 오늘 잠실에서 만나서 식당가에서 밥을 먹기로 했다.
#
# ['강의실에서 페이스북(페북)을 해서 응원할 때 입을 티를 사러 갈 시간이', '강의실에서 페이스북(페북)을 하고 응원할 때 입을 티를 사러 간다.', '강의실에서 페이스북(페북)을 하고 응원할 때 입을 티를 사러 갈 시간이']
# 응원할 때 입을 티 사러 함께 가기로 했다.
#
# ['코로나가 끝나면 보라카이에 가자고 한다.', '코로나 끝나면 보라카이에 가고 싶다.', '코로나가 끝나면 보라카이에 가자고 이야기한다.']
# 코로나가 끝나면 보라카이와 세부를 가자고 하고 있다.
#
# ['언니가 11시 좀 전에 퇴근하고 오는데 오전에도 괜찮다고 한다.', '언니가 11시 좀 전에 퇴근을 하고 오후에 5시쯤에 가기로 했다.', '언니가 11시 좀 전에 퇴근하고 오는데 오전에도 괜찮다고 해서 전화하겠다고 한다.']
# 언니에게 편하실 때 오라고 하고 전화하겠다 말한다.
#
# ['동생이 언니 신혼여행을 어디로 가는지 물어봤는데 제주도에 가는 거 아니냐고', '동생이 언니 신혼여행을 어디로 가는지 물어봤는데 제주도 가는 거 아니냐고 했다.', '동생이 언니 신혼여행을 어디로 가는지 물어봤는데 제주도 가는 거 아니냐고 해서']
# 언니가 신혼여행을 제주도로 가는 게 아닌가 하고 물어봤지만 유럽으로 간다고 하자 위험하다고 걱정한다.
#
# ['내일 유가네에서 만나서 점심을 먹기로 했다.', '내일 유가네에서 만나서 같이 점심을 먹기로 했다.', '내일 1시 40분에 유가네에서 만나서 점심을 먹기로 했다.']
# 내일 점심을 먹을지 무엇을 먹을지 상의한다.
#
# ['다음 주 화요일에 병원에 간다고 해서 월요일쯤에 만나기로 했다.', '다음 주 화요일에 병원에 간다고 해서 월요일쯤에 만나기로 했다.', '다음 주 화요일에 병원에 간다고 해서 월요일에 만나기로 했다.']
# 다음 주 화요일 병원에 가는데 그날 만나기로 했다.
#
# ['예산은 200만 원인데 제주도에서 일주일 내내 물놀이를 한다.', '예산은 200만 원인데 제주도에서 일주일 내내 물놀이를 하면 좋을 것 같다.', '예산은 200만 원인데 제주도에서 일주일 내내 물놀이를 하면 좋겠다고 한다.']
# 제주도의 새로운 곳을 찾아 여행하기로 하고 일주일 동안 총 휴가비 예산은 200만 원 정도이다.
#
# ['운동 끝나고 바로 가면 12시 반에 도착할 것 같다고 해서 12시 반에 만나기로', '운동 끝나고 바로 가면 12시 반 전에 도착할 것 같아서 12시 반에 만나기로 했다.', '운동 끝나고 바로 가면 12시 반 전에 도착할 것 같아서 12시 반에 만나기로 했다.']
# 내일 12시 반에 만나서 점심을 먹기로 했다.
#
# ['결제가 떨어졌는데 메일 온 것을 캡처해 달라고 한다.', '결제가 떨어졌는데 메일 온 것을 캡처해달라고 한다.', '결제가 떨어졌는데 메일 온 것을 캡처해 달라고 한다.']
# 메일이 온 것을 캡처해 주면 내가 직접 호텔에 메일을 해서 확인해야겠다.
#
# ['지금 과외가 끝나서 표 사려고 하는데 검색해보니 진에어를 타야', '지금 과외가 끝나서 표 사려고 하는데 검색해본 결과 진에어를 타', '과외가 지금 끝나서 표 사려고 하는데 검색해보니 진에어를 타야']
# 12시에 출발하는 진에어 비행기표를 사기로 했다.
#
# ['목요일 오전 11시부터 공강이라 아침에 헬스를 가기로 했다.', '목요일 오전 11시부터 공강이라 아침에 헬스를 가기로 했다.', '목요일 오전 11시부터 공강이니 아침에 헬스를 가도 되겠다고 한다.']
# 목요일 오전에 수업이 없으니 아침에 헬스를 가면 되겠다.
#
# ['지금 키즈 카페(키카)에서 나와서 걸어가고 있다.', '지금 키즈 카페(키카)에서 나와서 걸어가고 있다.', '키즈 카페(키카)에서 만나기로 했는데 배가 고파서 걸어가기로 했다.']
# 점심은 안 먹고 가는데 키즈 카페(키카)에서 지금 나왔고 놀이터(놀터)에서 또 놀 듯하니 배가 고프지만 점심을 먼저 먹으라고 한다.
#
# ['산부인과는 저번에 다녀온 곳이고 비뇨기과로 갈까 고민 중', '산부인과는 저번에 다녀온 곳이고 비뇨기과는 저번에 다녀온 곳', '산부인과는 저번에 다녀온 곳이고 비뇨기과로 갈지 고민 중']
# 산부인과와 비뇨기과 중에 비뇨기과가 나을 것 같다.
#
# ['수요일 저녁에 엄마가 데리러 간다고 한다.', '수요일 저녁에 엄마가 데리러 가기로 했다.', '수요일 저녁에 엄마가 데리러 가기로 했다.']
# 샌프란시스코(샌프란)에 도착하면 수요일 저녁에 파티를 할 생각이다.
#
# ['호텔에 같이 가면 조식 없이 3명 할까 아니면 둘이 조식 포함으로 할까', '호텔에 같이 가면 조식 없이 3명 할까 아니면 둘이 조식 포함할지 이야기하고', '호텔에 같이 가면 조식 없이 3명 할까 아니면 둘이 조식 포함할까 고민']
# 대화자 2명만 갈지, 같이 갈지에 따른 조식과 침대, 날짜를 이야기하다가 21일 또는 28일에 둘이 가는 것으로 잡자고 한다.
#
# ['언니가 코스트코에 1시 반쯤 가기로 했다.', '언니가 코스트코에 1시 반쯤 가기로 했다.', '언니에게 코스트코에 1시 반쯤 가자고 한다.']
# 일 다 했으면 1시 30분쯤에 코스트코에 가자고 한다.
#
# ['언니를 봐야 해서 27일에 오라고 했는데 언니가 일을 한다고 해서 그때 가겠다고 한다.', '언니를 봐야 해서 27일에 오라고 했는데 언니가 일을 한다고 한다.', '언니를 봐야 해서 대구에 27일에 오라고 한다.']
# 시간이 되면 27일 대구에 가겠다고 말하고 있다.
#
# ['처음 보는 사람도 있었고 처음엔 어색해서 생각보다 말이 길어져서 교리 공부도', '처음 보는 사람도 있었고 처음엔 어색해서 생각보다 말이 길어졌다.', '처음 보는 사람도 있었고 처음엔 어색해서 생각보다 말이 길어졌다.']
# 처음 보는 사람들과 뻘쭘하게 자기소개도 하느라 말이 길어졌다.
#
# ['유럽 여행 갈 때 캐리어가 분실될 수 있어서 이번 여행은 안 된다고 한다.', '유럽 여행할 때 캐리어가 분실될 수 있어서 이번 여행은 안된다고 한다.', '유럽 여행 갈 때 캐리어가 분실될 수 있어서 이번 여행은 안된다고 한다.']
# 유럽 여행 때 짐 최소화하고 본인도 살게 많아서 이번 여행은 안된다고 말했다.
#
# ['금요일에 분당에서 영화를 보고 토요일에 다시 보자고 한다.', '금요일에 분당에서 영화를 보고 토요일에 다시 보자고 한다.', '금요일에 분당에서 영화를 보고 토요일에 다시 보자고 한다.']
# 금요일에 분당에서 만났다가 토요일에 다시 보는 게 좋을 것 같다.
#
# ['내일 부산을 가는데 옆 동네도 아니고 전날 급하게 부산을 간다고 한다.', '내일 부산을 가는데 옆 동네도 아니고 전날 급하게 급하게 부산을 간다.', '내일 부산을 가는데 옆 동네도 아니고 전날 급하게 급하게 부산에 간다고']
# 부산에 가는데 전날 급하게 하고 있다.
#
# ['둘째 날 숙소 빼고 숙소비 한 번 더 빼면 35만 원 정도 남아서', '둘째 날 숙소 빼고 숙소비 한 번 더 빼면 35만 원 정도 남을 거', '제주도 여행 계획을 짜는데 큰돈은 다 결제된 것 같고 게시판에 쓴 돈은']
# 제주도 여행 계획을 정하고 있고 숙소 한곳만 빼고 모두 결제를 한 것 같다.
#
# ['내일로 생각하고 다른 약속을 안 잡았는데 시간 정하잔 말이 없길래 물어', '내일로 생각하고 다른 약속을 안 잡았는데 시간 정하잔 말이 없어서 물어봤다.', '내일로 생각하고 다른 약속을 안 잡았는데 다음 주에 부평에 올뻔했다.']
# 내일이 아니고 다음 주가 약속 일이다.
#
# ['방 하나를 찾는 중인데 시작한 지 얼마 안 됐다.', '방 하나를 찾는 중인데 시작한 지 얼마 안 됐다.', '방 하나를 찾는 중인데 시작한 지 얼마 안 됐다.']
# 시작 한지 얼마 안 되었고 5명에 방이 1개이다.
#
# ['내일 아침에 운동을 가서 10시 50분에 끝나서 롯데리아 정류장에 11시쯤 도착할', '내일 아침에 운동을 가서 롯데리아 정류장에 11시쯤 도착할 것 같다.', '내일 아침에 운동을 가서 10시 50분에 끝나서 롯데리아 정류장에 11시쯤에 도착']
# 내일 11시까지 롯데리아 정류장으로 가기로 한다.
#
# ['오늘 저녁에 폴에 가서 커피를 마시기로 했다.', '오늘 저녁에 폴에 가서 커피를 마시자고 한다.', '오늘 저녁에 폴에 가서 커피를 마시자고 한다.']
# 오늘 저녁에 같이 커피를 마시자고 한다.
#
# ['저녁하기 귀찮아서 회사에서 먹고 퇴근하면 배신이라고 하자 함께 먹으라고 한다.', '저녁하기 귀찮아서 회사에서 먹고 퇴근하면 배신이라고 하자 함께 먹으라고 하고', '저녁하기 귀찮아서 회사에서 먹고 퇴근하면 배신이라고 하니 함께 먹으라고 한다.']
# 저녁 하기 귀찮아서 회사에서 먹고 퇴근하려 하였지만, 약속을 지키기 위해서 마트에 가는 것이 귀찮더라도 같이 먹을 것이다.
#
# ['집에 일이 있어서 팬 콘서트(팬콘)에 못 갈 것 같아서 둘이 화통에 가서', '집에 일이 있어서 팬 콘서트(팬콘)를 못 갈 것 같아서 둘이 잘 봐야 한다고 한다.', '집에 일이 있어서 팬 콘서트(팬콘)에 못 갈 것 같아서 둘이 화통에 가']
# 이번에 집에 일이 있어서 팬 콘서트(팬콘)에 못 갈 것 같다.
#
# ['늦잠을 자서 천천히 저녁때 갈 테니 천안으로 오라고 한다.', '늦잠을 자서 천천히 저녁때 갈 테니 천안으로 오라고 한다.', '늦잠을 자서 천천히 저녁때 천안에 가려고 한다.']
# 천안에 있는 사람과 몇 시에 볼지 이야기한다.
#
# ['겨우 타서 사거리 오면 알려달라고 한다.', '겨우 타서 사거리 오면 알려달라고 한다.', '겨우 타서 사거리 오면 알려달라고 한다.']
# 약속에 나가기 위해 뛰어서 대중교통을 간신히 탔다고 대화하고 있다.
#
# ['다음 달(담달)에 롯데월드에 가기로 했다고 미리 섭외를 하라고', '다음 달(담달)에 롯데월드를 가기로 해서 미리 섭외를 하라고', '다음 달(담달)에 롯데월드에 가기로 해서 미리 섭외를 하라고']
# 다음 달(담 달)에 롯데월드를 팔월 언제 갈 건지 약속을 잡아놓으라고 한다.
#
# ['패러글라이딩을 꼭 해보고 싶은데 개강 전에 당일치기로 다녀오', '패러글라이딩을 꼭 해보고 싶은데 개강 전에 당일치기로 다녀올', '패러글라이딩을 꼭 해보고 싶은데 개강 전에 당일 치기로 다녀오']
# 단양에 가서 패러글라이딩을 하고 싶은데 멀어서 당일치기로 다녀오는 것은 힘들 것 같다.
#
# ['오늘 술을 적당히 마시려고 했는데 막차 때문에 다섯 시간만 놀다 와야 한다.', '오늘 을지로에 가는데 막차 때문에 다섯 시간만 놀다 와야 해서 술을', '오늘 술을 적당히 마시려고 했는데 막차 때문에 다섯 시간만 놀다 와야 해서']
# 스트레스를 받아서 을지로에서 술을 많이 마실 것 같고 12시에 부천으로 오라고 한다.
#
# ['오늘은 언니가 약속이 있어서 다음 주에 만나기로 한다.', '오늘 약속이 있어서 다음 주(담주)에 만나기로 했다.', '오늘 약속이 있어서 다음 주(담주)에 만나기로 했다.']
# 오늘 보자고 하는 말에 오늘은 언니가 약속이 있고 다음 주에 보자고 하자 5시 30분에 퇴근이라고 한다.
#
# ['내일 몇 시에 만날지 이야기하고 노트북을 충전해 간다고 하고 더 놀고 싶', '내일 몇 시에 만날지 이야기하고 노트북을 충전해 간다고 한다.', '내일 12시에 만나서 노트북을 충전하고 놀기로 했다.']
# 노트북과 충전기를 챙겨오고  점심 식사 후 12시 반이나 한시에 만나서 놀겠다.
#
# ['초코 선데이를 먹으러 가려고 지금 성서역에서 내려서 택시를', '초코선데이를 먹으러 가려고 지금 성서역에서 내려서 택시를', '초코 선데이를 사서 가려고 성서역에서 택시를 타고 나왔다.']
# 초코 선데이를 사서 성서 IC에 내렸는데 택시 내렸던 곳으로 나오라고 하였다.
#
# ['날씨 좋으니까 먹고 걷자고 하며 다대포 투어를 시켜준다고 하고 편하게 입고', '날씨 좋으니까 먹고 걷자고 하니 다대포 투어를 시켜준다고 편하게 입고 오', '다대포 투어를 시켜줘서 편하게 입고 가고 가방도 편한 거 매']
# 날씨가 좋아서 밥을 먹고 다대포 투어를 시켜줄 테니 편하게 입고 오라는 이야기를 하고 있다.
#
# ['시간이 안 맞아서 다음 주에 만나기로 했고 내일도 간단하게 먹고 들어오면 된다.', '시간이 안 맞아서 다음 주에 만나기로 했는데 내일도 간단하게 먹고 들어오면 된다.', '시간이 안 맞아서 다음 주에 만나기로 했는데 내일도 간단하게 먹고 들어오기로 했다.']
# 시간이 안 맞아서 다다음주 에 만나려다가 일요일에 둘이 간단하게 만나려고 한다.
#
# ['수요일 약속은 간단하게 밥 먹고 차 마시는 고전적인 코스가 나을 것 같', '수요일 약속은 간단하게 밥 먹고 차 마시는 정도의 고전적인 코스가 나을 것', '수요일 약속은 간단하게 밥 먹고 차 마시는 고전적인 코스가 나을 거 같']
# 수요일은 상대방이 약속이 있어서 밥 먹고 차를 마시는 코스가 좋겠다고 하고 강남에서 보기로 한다.
#
# ['남자 친구(남친) 생일이 2주라서 호텔에 가서 식사권을 사려고', '남자 친구(남친) 생일이 2주라서 식사권을 팔지 않고 호텔', '남자 친구(남친) 생일이 2주인데 어디 갈지 고민하다가 신라호텔에']
# 2주 뒤에 남자친구 생일이라 신라호텔에 가서 식사를 할까 생각 중이다.
#
# ['수요일에 언니랑 호텔 바캉스(호캉스)를 가는데 방이 두 개', '이번 주 수요일에 언니랑 호캉스를 가는데 방 두 개를 잡았다.', '수요일에 언니랑 호텔 바캉스(호캉스)를 가는데 방 두 개를 예약']
# 수요일에 언니와 호캉스를 갈 것이고 목요일 점심을 어디로 먹으러 가면 좋을지 물어보고 있다.
#
# ['스위스에서 어떻게 2층 침대로 올라갔는지 기억도 안 나고 술 마신 기억밖에 없다.', '스위스에서 어떻게 2층 침대로 올라갔는지 기억도 안 나는데 술 마신 기억밖에', '스위스에서 어떻게 2층 침대로 올라갔는지 기억이 안 난다고 한다.']
# 스위스에서 술 마셨던 기억을 회상하고 있다.
#
# ['체험단으로 양 꼬치에 당첨됐는데 친구랑 같이 가자고 하니 날짜가 애매', '체험단으로 양 꼬치에 당첨됐는데 친구랑 같이 가자고 하자 날짜가 애매', '체험단으로 양 꼬치에 당첨이 됐는데 친구와 같이 갈지 물어보고 있다.']
# 송정역 양 꼬치 체험단으로 당첨돼서 같이 가려고 날짜와 인원에 대해 이야기한다.
#
# ['배표가 취소돼서 9일에 숙소를 예약해 놨는데 전화 와봐야 알', '9일 날 숙소 예약이 취소돼서 9일 날 숙소 예약을 걸어놨는데', '배표가 취소돼서 9일에 숙소를 예약해 놨는데 8일은 배편이']
# 예약해둔 배표가 취소되었고 다른 날짜로 예약을 해두었음을 이야기하고 있다.
#
# ['강남대로 오면 지하철을 타고 같이 시내를 가면 될 것 같다.', '강남대로 오면 지하철을 타고 같이 시내에 가면 될 것 같다고 한다.', '강남대로 오면 같이 지하철을 타고 같이 시내를 가면 될 것 같다.']
# 같이 강남대역에서 같은 지하철을 타고 시내 가자고 하고 있다.
#
# ['여행에서 돈도 많이 쓰고 유니클로에서 이만 오천 원짜리 겨울옷을', '여행에서 돈도 많이 쓰고 유니클로에서 이만 오천 원짜리 겨울 옷도', '여행에서 돈도 많이 쓰고 유니클로에서 이만 오천 원짜리 겨울옷도']
# 여행 가서 38만 원 쓰고 남은 돈으로 쇼핑하느라 공항에서 밥을 먹으려고 한다.
#
# ['금요일에 만나서 대창덮밥을 먹으러 성수이나 상수에 가자고', '금요일에 만나서 대창덮밥을 먹으러 가기로 했다.', '금요일에 만나서 대창덮밥을 먹으러 성수이나 상수에 가기로']
# 금요일에 만나서 하고 싶은 것 하자고 하자 대창도 먹고 싶은데 수다면 된다고 한다.
#
# ['이번 달 초중반에 몇 개 약속이 있어서 이번 달 말 괜찮은지 물어', '10월 초중반에 몇 개 약속이 있어서 이번 달 말 괜찮은지 물어본', '이번 달 초중반에 몇 개 약속이 있어서 이번 달 말 괜찮냐고 물으니']
# 10월에 한 사람은 아무 약속이 없는데 한 사람은 초중반에 몇 개의 약속이 있어 이번 달 말에 만나기로 한다.
#
# ['1월 18일 목요일 2시에 예약을 했다.', '1월 18일 목요일 2시에 예약을 했다.', '1월 18일 목요일 2시에 예약을 했다.']
# 1월 18일 목요일 2시에 상대방 것을 예약했다.
#
# ['일 끝나고 전주 식당을 찾아보라고 하자 국밥을 먹고 점심 먹고 저녁을 먹고', '일 끝나고 전주 식당을 찾아보라고 하니 국밥을 먹고 점심 먹고 저녁을 먹고', '일 끝나고 전주 식당을 찾아보라고 하니 국밥 먹고 점심 먹고 저녁 먹고 와야']
# 단체 카카오톡(단톡)에 전주 식당을 찾아서 몇 개 보냈었다고 하니까, 추려야 한다고 한다.
#
# ['영화 극한 직업이 보고 싶다고 해서 그 날 밥 먹고 경대에 가서 영화를 보', '영화 극한 직업이 보고 싶다고 하니 그 날 밥 먹고 경대에 가서 영화를 보', '영화 극한 직업이 보고 싶다고 해서 그 날 밥을 먹고 경대에 가서 영화를 보']
# 영화 극한 직업을 보고 싶어서 같이 밥을 먹고 경대에 가서 보기로 했다.
#
# ['이번 주 금요일에 단체 카카오톡(단톡)에 닭발을 시켜 먹을지 아니면 만들어 먹을', '이번 주 금요일에 단체 카카오톡(단톡)에 닭발을 시켜 먹을 건지 아니면 만들어', '이번 주 금요일에 단체 카카오톡(단톡)에서 닭발을 시켜 먹을지 아니면 만들어 먹을']
# 모임 약속을 언제 잡을지 묻고 닭발을 시켜 먹으면 비쌀지 이야기한다.
#
# ['일요일에 엄마 생신이라서 같이 가자고 한다.', '일요일에 엄마 생신이라 엄마랑 같이 가자고 한다.', '일요일에 엄마 생신이라서 같이 가자고 한다.']
# 일요일(일욜)에 시간이 되는지 궁금해하자 그날은 엄마의 생신이라서 안된다고 하자 같이 가서 엄마에게 재롱을 부리자고 한다.
#
# ['16일 금요일에 안면도에서 만나기로 했다.', '16일 금요일 금요일에 안면도에서 만나기로 했다.', '16일 금요일에 안면도에서 만나기로 했다.']
# 일산에서 네시쯤 출발하고 따로 여산에서 출발하는 지인도 있다.
#
# ['남이섬에서 호떡을 먹고 있는데 내일 시험이 있는 사람들만 하루 일찍 가', '남이섬에서 호떡을 먹고 있는데 내일 시험인 사람들만 하루 일찍 가라고', '남이섬에서 호떡을 먹고 있는데 내일 시험인 사람들만 일찍 가라고 했다.']
# 남이섬에 왔다가 내일 시험이 있어서 오늘 저녁에 간다고 이야기하고 있다.
#
# ['금요일은 출근이 12시라 빠른 시간대가 좋다.', '금요일은 출근이 12시라 빠른 시간대가 좋다.', '금요일은 출근이 12시라 빠른 시간대가 좋다.']
# 금요일은 출근이 12시라서 12시로 예약을 한다고 했다.
#
# ['예약하는 건 아니고 8월에 한 것과 주말에 할 거랑 위치가 다르다.', '예약하는 건 아니고 8월에 한 것과 주말에 할 거랑 위치가 다르다고 한다.', '예약하는 건 아니고 8월에 한 것과 주말에 할 거랑 위치가 달라서 그냥']
# 지금 예약하는 것은 아니고 8월과 주말에 하는 것은 위치가 다르고 무료도 있고 유료입장도 있다.
#
# ['보라매에 우리 집주인이 하는 족발집이 있어서 신삼역에서 만나기로', '보라매에 우리 집주인이 하는 족발집이 있어서 신삼역으로 간다.', '보라매에 우리 집주인이 하는 족발집이 있어서 신삼역으로 가기로']
# 언니가 족발을 먹기 위해 신삼으로 가려고 한다.
#
# ['부산 기장에 글램핑하기 좋았던 곳은 기장 바로 옆에 있고 경치도', '부산 기장에 글램핑하기 좋았던 곳은 기장 바로 옆에 있고 경치가 좋고', '부산 기장에 글램핑하기 좋았던 곳이 기장 바로 옆에 있고 경치도']
# 부산 기장 바로 옆쪽에 글램핑하기 좋았던 곳이 있다고 말하고 있다.
#
# ['누나가 방사능 때문에 일본 음식을 안 먹는다.', '누나가 방사능 때문에 초밥도 안 먹고 회도 안 먹는다고 이야기하고 있다.', '누나가 방사능 때문에 초밥도 안 먹고 회도 안 먹는다고 한다.']
# 누나는 일본 방사능 때문에 가는 것도 싫고 음식 음식도 안 먹는다.
#
# ['홍대에 있는 카페에 와서 신나게 놀고 있다.', '홍대에 있는 카페에 와서 신나게 놀고 있다고 한다.', '홍대에 있는 카페에 와서 신나게 놀고 있다고 한다.']
# 홍대에 있는 카페에 와서 사진으로 보여준다.
#
# ['가본 적이 있는데 왜 안 가본척하냐고 하자 올해는 가본 적이 없어서 낯', '가본 적이 있는데 왜 안 가본 척하냐고 하자 올해는 가본 적이 없어서 낯', '가본 적이 있는데 왜 안 가본척하냐고 하자 올해는 가본 적이 없다고 한다.']
# 가본 적 있는 장소지만 올해는 가지 않아 낯설게 느껴져 안 가본 척했다고 한다.
#
# ['내일 점심을 먹고 코코볼을 들고 가기로 한다.', '내일 점심을 먹고 코코볼을 들고 가기로 했다.', '내일 점심을 먹고 코코볼을 들고 가기로 한다.']
# 코코볼 들고 갔냐고 하며 상대방에게 다 가지라고 하자 상대방은 점심때 먹고 11시쯤 들고 가겠다며 내일 보자고 한다.
#
# ['가족 명절에 인천 영종도에 새로 생긴 수영장 있는 호텔로 호캉스를 가', '가족 명절에 호캉스를 가기로 했고 인천 영종도에 새로 생긴 호텔도', '가족 명절에 인천 영종도에 새로 생긴 수영장 있는 호텔로 가기로 했다.']
# 명절에 가족과 함께 호텔 바캉스(호캉스)를 가기로 했고 인천 종도에 새로 생긴 서울보다 저렴한 호텔을 조식과 수영장을 포함해서 20만 원에 간다.
#
# ['오늘 회식인데 혼자 저녁을 먹는다고 한다.', '오늘 회식이라 혼자 저녁을 먹는다고 한다.', '오늘 회식이라 혼자 저녁을 먹는다고 한다.']
# 오늘 회식이지만 늦게 오진 않을 건데 저녁을 혼자 먹어야 한다.
#
# ['런던 비행기 표가 23일 표라서 금방 매진될 것 같고 방콕 표', '런던 비행기가 23일 표라서 금방 매진될 것 같고 방콕 표가 취소', '런던 비행기 표가 23일 표라 금방 매진될 것 같고 방콕 표가']
# 런던행 비행기 표를 예매하기로 결정한다.
#
# ['일단 장지역에서 기다리고 있을지 집 근처에 있는 티지아이를 갈지 고민한다.', '일단 장지역에서 기다리고 있을지 집 근처에서 기다릴지 티지아이를 갈지', '일단 장지역에서 기다리고 있을지 집 근처에 있는 티지아이를 갈지 고민하고']
# 고기를 먹을지 티지아이를 갈지 고르라고 하니 아무거나 상관없다고 한다.
#
# ['12일은 개인 카카오톡(갠톡)이 가능한 날이라서 12일에 부산에 가자고', '12일은 개인 카카오톡(갠톡)이 가능한 날이라서 12일에 부산에 가기로', '12일은 개인 카카오톡(갠톡)이 가능한 날이라서 12일에 부산에 갈 것이다.']
# 21일에는 부산에 갈 것이고 12일에는 개인 톡을 하며 같이 놀기로 했다.
#
# ['내일 저녁으로 교재 연구하다가 저녁을 먹으러 가겠다고 한다.', '내일 저녁으로 교재 연구하다가 저녁을 먹으러 가겠다.', '내일 저녁으로 교재 연구하다가 저녁을 먹으러 가겠다.']
# 내일 수능이랑 겹쳐 여기저기에 사람이 많을 것 같아 6시에 저녁만 빨리 먹고 집으로 가서 와인을 마시기로 한다.
#
# ['일요일(일욜)에 범계에서 만나서 맥주를 먹기로 했다.', '일요일(일욜)에 범계에서 만나서 맥주를 먹고 수원에 가서 밥을 먹', '일요일(일욜)에 범계에서 만나서 맥주를 먹기로 했다.']
# 일요일에 수원에서 밥을 먹고 카페에 갔다고 저녁에 범계에 가서 맥주를 마시기로 했다.
#
# ['방금 광안리에서 둘이 한 시간 이야기하고 갔다.', '방금 광안리에서 둘이 한 시간 이야기를 하고 갔다.', '방금 광안리에서 둘이 한 시간 이야기하고 갔다.']
# 광안리에서 지인을 만나서 한 시간 얘기했다.
#
# ['금요일에 안산으로 면접을 보러 간다.', '금요일에 안산으로 면접을 보러 간다고 한다.', '금요일에 안산으로 면접을 보러 간다고 한다.']
# 금요일에 안산에서 면접을 볼 것에 대해 이야기하고 있다.
#
# ['영화 몇 시 꺼 볼 건지 묻자 10분에 보자고 한다.', '영화 몇 시 꺼를 볼 거냐고 묻자 10분에 보자고 한다.', '영화 몇 시 꺼를 볼 거냐고 물으니 10분에 보자고 한다.']
# 아줌마가 4시 10분 영화를 보자고 이야기한다.
#
# ['일본에 갈 때 유카타를 입고 올림머리 하면 귀여울 것 같다.', '일본에 갈 때 마츠리 기간이라 유카타를 입고 올림머리를 하면 귀', '일본에 갈 때 유카타를 입고 올림머리를 하면 귀엽겠다며 비녀']
# 일본 갈 때 마츠리 기간이니 유카타 입고 비녀 꽂으라고 하니 언니가 자신이 없다고 한다.
#
# ['드레스 입은 것을 프로필 사진(프사)으로 해두면 청첩장을 안', '드레스 입은 것을 프로필 사진(프사)로 해두면 청첩장 안', '드레스 입은 것을 프로필 사진(프사)로 해두면 청첩장을 안']
# 어색하더라도 웨딩촬영을 잘 하고 오라고 응원해 준다.
#
# ['교회 친구들과 빨리 퇴사 기념 파티를 하자고 이야기하고 있다.', '교회 친구들이랑 빨리 퇴사하고 퇴사 기념 파티하자고 말하는데 우리 둘 다 퇴', '교회 친구들이랑 빨리 퇴사하고 퇴사기념 파티하자고 말하는데 우리 둘 다 퇴']
# 둘 다 퇴사를 하면 퇴사 기념 파티를 하기로 했다.
#
# ['세계 와인이 다 모였다며 대전 무역 박람회장에서 하는 와인 박람회에 같이 가', '세계 와인이 다 모였으니 내일 대전 무역 박람회장에서 하는 와인 박람회에 같이', '세계 와인이 다 모였다며 대전 무역 박람회장에서 하는 와인 박람회에 가자고']
# 오늘 와인 박람회를 가자고 질문해서 못 간다 대답한다.
#
# ['내일 집에 있다가 이마트에 가기로 했다.', '내일 집에 있다가 이마트에 가기로 했다.', '내일 집에 있다가 이마트에 가기로 했다.']
# 내일 이마트에 갈 거라고 한다.
#
# ['중심 쇼핑몰이 문을 닫아서 차이나타운을 구경하고 왔다.', '중심 쇼핑몰이 문을 닫아서 차이나타운을 구경하러 왔다.', '중심 쇼핑몰이 문을 닫아서 차이나타운에 구경 왔다.']
# 시차가 2시간 차이인 곳의 차이나타운을 구경 갔다 왔다.
#
# ['언니가 토요일 저녁쯤에 보자고 하자 시험 기간과 과외 수업 준비 때문에 늦', '언니가 토요일 저녁쯤에 보자고 하자 시험 기간 일요일 과외 수업 준비 때문에 늦', '언니가 토요일 저녁쯤에 보자고 하자 시험 기간과 과외 수업 준비로 늦']
# 일요일 과외 수업 준비 때문에 토요일 저녁 늦게는 보기에는 부담스러워 낮에 보기로 한다.
#
# ['내일 중앙시장에 가서 보리밥이라도 먹자고 한다.', '내일 시장 중앙식당에서 보리밥을 먹기로 했다.', '내일 시장 중앙식당에서 보리밥을 먹기로 했다.']
# 내일 아침에 중앙시장으로 가서 보리밥을 먹기로 한다.
#
# ['전주는 군산과 한 묶음이고 제주도는 진짜 가고 싶어서 가을에 군산에', '전주는 군산과 한 묶음이고 제주도는 진짜 가고 싶다.', '전주는 군산과 한 묶음이고 제주도는 진짜 가고 싶다.']
# 군산은 더워서 가을에 가야 하고 전주는 군산이랑 한 묶음이고 제주도도 가을에 가고 싶다.
#
# ['우리가 산 것이 수영장이 아니라 워터파크인데 오전에 좀 놀다가 지겨워', '우리가 산 것은 수영장이 아니라 워터파크인데 오전에 좀 놀다가 지겨워', '우리가 산 것이 수영장이 아니라 워터파크인 것을 알고 있고 오전에 좀 놀다가']
# 오전에 워터파크에서 놀다가 지겨워질 때쯤 나가기로 한다.
#
# ['오늘 퇴근하고 산본에 애들이랑 쌀국수를 먹으러 간다고 한다.', '오늘 퇴근하고 산본에 애들이랑 쌀국수를 먹으러 간다.', '오늘 퇴근하고 산본에 애들과 쌀국수를 먹으러 간다.']
# 퇴근하고 산본에 쌀국수를 먹으러 간다고 한다.
#
# ['6시에 손님이 오는데 여섯시 반에 오면 조금 기다려야 한다.', '6시에 손님이 오는데 여섯시 반쯤 가서 기다리기로 했다.', '6시에 손님이 오는데 여섯시 반에 오면 조금 기다려야 한다고 한다.']
# 여섯 시 반에 오면 조금 기다려야 할 거 같다고 하자 여섯 시 반쯤 가서 기다린다고 한다.
#
# ['첫날에 함덕을 취소하고 첫날에 바로 서귀포로 가고 두 번째 날에 성', '함덕을 취소하고 첫날에 바로 서귀포로 가고 두 번째 날에 그대로 성산을', '함덕을 취소하고 첫날에 바로 서귀포로 가고 두 번째 날에 성산을 가고']
# 첫째 날과 둘째 날의 여행 계획을 짜고 있다.
#
# ['근처에 맛있는 라멘집이 있는 곳인데 부천에서 나름 비싼 아파트 1층 상권이다.', '근처에 맛있는 라멘집이 있는 곳인데 부천에서 나름 비싼 아파트 1층 상권이라고', '근처에 맛있는 라멘집이 있는 곳인데 부천에서 나름 비싼 아파트 1층 상권이라']
# 가려던 곳 근처 비싼 아파트 1층 상권에 맛있는 라멘집이 있다.
#
# ['쌀국수를 먹으러 가자고 하니 괜찮다고 먼저 가 있으라고 한다.', '쌀국수를 먹으러 가자고 하니 괜찮다고 먼저 가 있으라고 한다.', '쌀국수를 먹으러 가자고 하니 괜찮다고 먼저 가 있으라고 한다.']
# 쌀국수를 먹으러 먼저 가 있겠다.
#
# ['로션은 샘플 하나만 챙기고 폼클렌징(폼클)만', '로션은 샘플 하나만 챙기고 폼클렌징(폼클)과 렌', '로션은 샘플 하나만 챙기고 폼클렌징(폼클)과 리']
# 로션을 챙겼냐고 물어봐서 에센스 하나를 챙겨서 괜찮다고 해서 폼 클렌징(폼클)과 렌즈 통도 챙겨야 한다고 이야기한다.
#
# ['자동차 극장은 다음에 가자고 한다.', '자동차 극장은 다음에 가기로 했다.', '자동차 극장은 다음에 가자고 하며 집에 갈 때 집에 가지 말라고 하자 그러면 갈 수']
# 내일 자동차 극장에 가기로 했지만 왔다 갔다 하면 너무 멀 것 같아 다음에 가기로 약속을 미뤘다.
#
# ['다음 달(담달)에 양양 솔비치를 빌려서 같이 가면 어떨까 했는데', '다음 달(담달)에 양양 솔비치를 빌려서 엄마랑 같이 가려고', '다음 달(담달)에 양양 솔 비치를 빌려서 엄마랑 같이 가려고']
# 다음 달(담 달)에 솔비치에 놀려가려고 하는데 아직 어린아이 때문에 고민이 된다고 하고 있다.
#
# ['스파 디럭스 호텔을 예약해야 하는데 이만 원 차이라 그냥 스위트 호텔을', '스파디럭스 호텔로 예약해야 하는데 이만 원 차이라서 그냥 스위트하자고', '스파디럭스 호텔로 예약해야 하는데 이만 원 차이라 그냥 스위트 호텔로']
# 호텔 예약을 해야 된다고 하여 스파 디럭스와 이만 원 차이니까 그냥 스위트룸을 하자고 말한다.
#
# ['한 끼도 안 먹어서 쓰러질 것 같다고 하였다.', '한 끼도 안 먹어서 쓰러질 것 같다고 하였다.', '한 끼도 안 먹어서 쓰러질 것 같다고 하였다.']
# 언니 회사 근처에서 친구랑 밥을 먹고 언니랑 집에 가려고 한다.
#
# ['나리타 공항에서 노숙한 것까지 알고 있어서 이번 여름휴가는 방콕에서', '나리타 공항에서 노숙한 것까지 알고 있어서 이번 여름휴가는 방콕으로', '나리타 공항에서 노숙한 것까지 알고 있어서 이번 여름휴가는 방콕에']
# 나리타 공항에서 노숙한 거까지 다들 안다면서 이제 절대 일본을 안 가고 여름휴가는 집에만 있겠다고 한다.
#
# ['언니가 씻는 게 귀찮아서 물어보는 줄 알았다고 하자 언니가 씻는', '언니가 씻는 게 귀찮아서 물어보는 줄 알았는데 씻는 것은 의사소통', '언니가 씻는 게 귀찮아서 물어보는 줄 알았다고 하자 언니는 씻어야']
# 준비를 하는 중에 안 씻어도 되는 질문에 서로 오해해 자신 보고 씻어야 되는지 물어본 줄 몰랐다고 이야기한다.
#
# ['오늘 11시 40분에 만나서 점심을 같이 먹기로 했다.', '오늘 11시 40분에 만나서 점심을 먹기로 했다.', '오늘 11시 40분에 만나서 점심을 같이 먹기로 했다.']
# 오늘 같이 점심을 먹자고 말하자 너무 행복해서 뭘 먹어도 좋다고 이야기한다.
#
# ['이번 주 토요일에 회사 언니랑 동생 만나기로 해서 이번 주 토요일에 회사 언니랑', '이번 주 토요일에 회사 언니랑 동생 만나기로 해서 이번 주 토요일에는 회사 언니랑', '이번 주 토요일에 회사 언니랑 동생 만나기로 해서 다음(담)에 희희라고']
# 이번 주 토요일에 회사 언니와 동생을 만나기로 해서 다음에 보기로 했다.
#
# ['전북 투어 패스를 쓸지 임실이나 치즈 마을에 갈지 이야기하고 있다.', '전북 투어 패스를 쓸지 임실이나 치즈 마을에 갈지 고민하고 있다.', '임실 치즈마을에 가서 전북 투어 패스를 쓰자고 한다.']
# 전북 투어패스를 받아서 임실의 치즈마을에 갈지 고민하고 있다.
#
# ['언니에게 연락해서 자유여행을 하라고 하였다.', '언니가 자유여행이니 언니에게 연락하라고 한다.', '언니가 자유여행이니 언니한테 연락하라고 한다.']
# 자유여행인데 계획을 짜는 게 쉬운 게 아니었다.
